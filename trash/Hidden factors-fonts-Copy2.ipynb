# %% [markdown]
# # Discovering hidden factors of variation in deep networks
#
# **This is an example of how to implement the autoencoder architecture from [Cheung et al. (2014)](http://arxiv.org/abs/1412.6583) in Lasagne.** This uses the code from the MNIST example bundled with Lasagne, so you will need to have the `mnist.py` file available for importing.

# %%
# %matplotlib inline
import os
os.environ["THEANO_FLAGS"]= "device=gpu1"

# %%
import numpy as np
import theano
import theano.tensor as T
import lasagne as nn
w, h = 64, 64
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# Using gpu device 1: Tesla K20m

# %%
from skimage.transform import resize
from skimage.filter import threshold_otsu

def binarize(X):
    X_b = np.empty(X.shape, dtype=X.dtype)
    for i in range(X.shape[0]):
        X_b[i] = 1. * (X[i] <= threshold_otsu(X[i]))
    return X_b

def resize_all(X, w, h):
    if X.shape[1] == w and X.shape[2] == h:
        return X
    X_b = np.empty((X.shape[0], w, h), dtype=X.dtype)
    for i in range(X.shape[0]):
        X_b[i] = resize(X[i], (w, h))
    return X_b

# %% [markdown]
# **We'll define the model listed in the first column of Table 1 in the paper.**
#
# This model has an encoder with two ReLU layers. In the paper they both have 500 units but we'll make this configurable so we can speed up the experiment a bit if necessary.
#
# On top of the encoder are two representation layers: one is a 10-way softmax layer which represents the class of the input. This is the observed representation layer. Then there is also a latent representation layer which has two additional linear units (the authors use only two units for easy visualization).
#
# Both representation layers are concatenated and the decoder is stacked on top. This consists of three layers: two hidden ReLU layers with again 500 units, and finally a linear reconstruction layer with 784 outputs.

# %%
def build_model(input_dim, output_dim, batch_size,
                num_hidden_units=500):
    l_in = nn.layers.InputLayer((batch_size, input_dim))
    
    # encoder
    l_encoder1 = nn.layers.DenseLayer(l_in, num_units=num_hidden_units)
    l_encoder2 = nn.layers.DenseLayer(l_encoder1, num_units=num_hidden_units)
    l_encoder3 = nn.layers.DenseLayer(l_encoder2, num_units=num_hidden_units)
    l_encoder4 = nn.layers.DenseLayer(l_encoder3, num_units=num_hidden_units)
    
    # learned representation
    l_observed = nn.layers.DenseLayer(l_encoder4, num_units=output_dim,
                                      nonlinearity=T.nnet.softmax)
    
    l_latent = nn.layers.DenseLayer(l_encoder4, num_units=2,
                                    nonlinearity=None) # linear
    
    l_representation = nn.layers.concat([l_observed, l_latent])
    
    # decoder
    l_decoder1 = nn.layers.DenseLayer(l_representation, num_units=num_hidden_units)
    l_decoder2 = nn.layers.DenseLayer(l_decoder1, num_units=num_hidden_units)
    l_decoder3 = nn.layers.DenseLayer(l_decoder2, num_units=num_hidden_units)
    l_decoder4 = nn.layers.DenseLayer(l_decoder3, num_units=num_hidden_units)
    l_decoder_out = nn.layers.DenseLayer(l_decoder4, num_units=input_dim,
                                       nonlinearity=None)
    
    return l_in, l_decoder_out, l_observed, l_latent

# %% [markdown]
# Next, **we'll define the cost function**. This consists of three parts: `alpha * U + beta * S + gamma * C` (formula 3 in the paper). `U` is the reconstruction cost, `S` is the supervised cost and `C` is the so-called "XCov" cost which disentangles the observed and latent variables of the encoder.

# %%
def cost(x, y, x_recon, y_pred, z, alpha=1.0, beta=10.0, gamma=10.0):
    """
    x, y: the input and the corresponding label
    x_recon: the model reconstruction of the input
    y_pred: the model prediction (observed variables)
    z: the latent variables
    """
    # reconstruction cost: mean squared error
    U = T.mean((x - x_recon)**2)
    
    # supervised cost: categorical cross-entropy
    S = T.mean(T.nnet.categorical_crossentropy(y_pred, y))
    
    # XCov cost: cross-covariance
    y_pred_mean = T.mean(y_pred, axis=0, keepdims=True)
    z_mean = T.mean(z, axis=0, keepdims=True)
    y_pred_centered = y_pred - y_pred_mean # (n, i)
    z_centered = z - z_mean # (n, j)
    
    outer_prod = (y_pred_centered.dimshuffle(0, 1, 'x') *
                  z_centered.dimshuffle(0, 'x', 1)) # (n, i, j)
    C = 0.5 * T.sum(T.sqr(T.mean(outer_prod, axis=0)))
    
    # the total cost is a weighted sum
    return alpha * U + beta * S + gamma * C

# %%
from lasagne.datasets.mnist import MNIST
from sklearn.cross_validation import train_test_split
import lasagne.easy

def load_data():
    """Get data with labels, split into training, validation and test set."""
    from lasagne.datasets.fonts import Fonts
    
    data = Fonts(kind="all_64",
                 labels_kind="letters")
    data.load()
    
    #data = MNIST()
    #data.load()
    
    X = data.X
    #X = X.reshape((X.shape[0], 28, 28))
    #X = resize_all(X, w, h)
    
    #X = binarize(X)
    X = 1 - X
    X = X.astype(np.float32)
    X = X.reshape((X.shape[0], w*h))
    y = data.y
    X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.25)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.25)
    
    return dict(
        X_train=theano.shared(lasagne.utils.floatX(X_train)),
        y_train=T.cast(theano.shared(y_train), 'int32'),
        X_valid=theano.shared(lasagne.utils.floatX(X_valid)),
        y_valid=T.cast(theano.shared(y_valid), 'int32'),
        X_test=theano.shared(lasagne.utils.floatX(X_test)),
        y_test=T.cast(theano.shared(y_test), 'int32'),
        num_examples_train=X_train.shape[0],
        num_examples_valid=X_valid.shape[0],
        num_examples_test=X_test.shape[0],
        input_dim=X_train.shape[1],
        output_dim=len(set(y)),
    )

# %% [markdown]
# Now let's tie everything together in the main training loop.

# %%
from mnist import train
import time

num_epochs = 200
batch_size = 100

print("Loading data...")
dataset = load_data()
print(dataset.keys())
# Out:
# Loading data...
# ['X_test', 'num_examples_train', 'X_train', 'num_examples_valid', 'num_examples_test', 'output_dim', 'X_valid', 'y_valid', 'y_train', 'input_dim', 'y_test']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-feca7b37c983> in <module>()
# ----> 1 dataset["y_train"].get_value()
#
# AttributeError: 'TensorVariable' object has no attribute 'get_value'

# %%
print("Building model and compiling functions...")
l_in, l_decoder_out, l_observed, l_latent = build_model(
    input_dim=dataset['input_dim'],
    output_dim=dataset['output_dim'],
    batch_size=batch_size,
)

x = l_in.input_var
y = T.ivector('y')
x_recon, y_pred, z = nn.layers.get_output([l_decoder_out, l_observed, l_latent])
# Note that we call get_output() once to get all the model outputs.
# This is to guarantee they are consistent and share computations where
# possible. When the network contains nondeterminism (such as dropout
# regularization), guaranteeing this consistency is crucially important.
loss = cost(x, y, x_recon, y_pred, z)
params = nn.layers.get_all_params(l_decoder_out)

# # add some L2 regularization
# params_reg = nn.layers.get_all_params(l_decoder_out, regularizable=True)
# reg = sum(T.sum(p**2) for p in params_reg)
# loss += 0.01 * reg

# The authors mention that they use adadelta, let's do the same
updates = nn.updates.adadelta(loss, params, learning_rate=0.1)

# compile iteration functions
batch_index = T.iscalar('batch_index')
batch_slice = slice(batch_index * batch_size,
                    (batch_index + 1) * batch_size)

pred = T.argmax(y_pred, axis=1)
accuracy = T.mean(T.eq(pred, y), dtype=theano.config.floatX)

iter_train = theano.function(
    [batch_index], loss,
    updates=updates,
    givens={
        x: dataset['X_train'][batch_slice],
        y: dataset['y_train'][batch_slice],
    },
)

iter_valid = theano.function(
    [batch_index], [loss, accuracy],
    givens={
        x: dataset['X_valid'][batch_slice],
        y: dataset['y_valid'][batch_slice],
    },
)

iter_test = theano.function(
    [batch_index], [loss, accuracy],
    givens={
        x: dataset['X_test'][batch_slice],
        y: dataset['y_test'][batch_slice],
    },
)

iter_funcs =  dict(
    train=iter_train,
    valid=iter_valid,
    test=iter_test,
)

print("Starting training...")
now = time.time()
try:
    for epoch in train(iter_funcs, dataset, batch_size=batch_size):
        print("Epoch {} of {} took {:.3f}s".format(
            epoch['number'], num_epochs, time.time() - now))
        now = time.time()
        print("  training loss:\t\t{:.6f}".format(epoch['train_loss']))
        print("  validation loss:\t\t{:.6f}".format(epoch['valid_loss']))
        print("  validation accuracy:\t\t{:.2f} %".format(
            epoch['valid_accuracy'] * 100))

        if epoch['number'] >= num_epochs:
            break

except KeyboardInterrupt:
    pass
# Out:
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 200 took 2.061s
#   training loss:		25.779125
#   validation loss:		20.077320
#   validation accuracy:		36.79 %
# Epoch 2 of 200 took 2.061s
#   training loss:		15.700170
#   validation loss:		12.986115
#   validation accuracy:		62.63 %
# Epoch 3 of 200 took 2.061s
#   training loss:		12.374366
#   validation loss:		11.703135
#   validation accuracy:		66.61 %
# Epoch 4 of 200 took 2.062s
#   training loss:		10.851155
#   validation loss:		11.137968
#   validation accuracy:		68.24 %
# Epoch 5 of 200 took 2.062s
#   training loss:		9.834286
#   validation loss:		9.600332
#   validation accuracy:		75.05 %
# Epoch 6 of 200 took 2.063s
#   training loss:		8.890220
#   validation loss:		7.978415
#   validation accuracy:		79.65 %
# Epoch 7 of 200 took 2.061s
#   training loss:		8.232944
#   validation loss:		8.017941
#   validation accuracy:		79.19 %
# Epoch 8 of 200 took 2.062s
#   training loss:		7.568221
#   validation loss:		7.360037
#   validation accuracy:		80.95 %
# Epoch 9 of 200 took 2.062s
#   training loss:		7.055826
#   validation loss:		7.158788
#   validation accuracy:		81.18 %
# Epoch 10 of 200 took 2.063s
#   training loss:		6.650538
#   validation loss:		6.964915
#   validation accuracy:		81.56 %
# Epoch 11 of 200 took 2.062s
#   training loss:		6.172253
#   validation loss:		6.927926
#   validation accuracy:		81.74 %
# Epoch 12 of 200 took 2.063s
#   training loss:		5.819561
#   validation loss:		6.673818
#   validation accuracy:		82.37 %
# Epoch 13 of 200 took 2.062s
#   training loss:		5.514979
#   validation loss:		6.511559
#   validation accuracy:		83.08 %
# Epoch 14 of 200 took 2.062s
#   training loss:		5.167901
#   validation loss:		6.704157
#   validation accuracy:		81.97 %
# Epoch 15 of 200 took 2.063s
#   training loss:		4.994526
#   validation loss:		6.143514
#   validation accuracy:		83.31 %
# Epoch 16 of 200 took 2.062s
#   training loss:		4.698378
#   validation loss:		6.116761
#   validation accuracy:		83.81 %
# Epoch 17 of 200 took 2.062s
#   training loss:		4.455246
#   validation loss:		6.082169
#   validation accuracy:		83.77 %
# Epoch 18 of 200 took 2.062s
#   training loss:		4.188042
#   validation loss:		5.936903
#   validation accuracy:		83.92 %
# Epoch 19 of 200 took 2.062s
#   training loss:		3.993060
#   validation loss:		5.987966
#   validation accuracy:		84.00 %
# Epoch 20 of 200 took 2.061s
#   training loss:		3.947546
#   validation loss:		6.329288
#   validation accuracy:		82.81 %
# Epoch 21 of 200 took 2.063s
#   training loss:		3.626776
#   validation loss:		6.036120
#   validation accuracy:		83.74 %
# Epoch 22 of 200 took 2.063s
#   training loss:		3.489481
#   validation loss:		5.939883
#   validation accuracy:		84.08 %
# Epoch 23 of 200 took 2.062s
#   training loss:		3.337645
#   validation loss:		5.948237
#   validation accuracy:		84.23 %
# Epoch 24 of 200 took 2.064s
#   training loss:		3.143698
#   validation loss:		6.132297
#   validation accuracy:		84.61 %
# Epoch 25 of 200 took 2.062s
#   training loss:		3.007986
#   validation loss:		6.433661
#   validation accuracy:		83.71 %
# Epoch 26 of 200 took 2.063s
#   training loss:		2.899472
#   validation loss:		6.082550
#   validation accuracy:		84.42 %
# Epoch 27 of 200 took 2.063s
#   training loss:		2.820752
#   validation loss:		6.559385
#   validation accuracy:		82.53 %
# Epoch 28 of 200 took 2.063s
#   training loss:		2.654469
#   validation loss:		5.827512
#   validation accuracy:		85.23 %
# Epoch 29 of 200 took 2.062s
#   training loss:		2.585137
#   validation loss:		6.039417
#   validation accuracy:		84.74 %
# Epoch 30 of 200 took 2.062s
#   training loss:		2.434012
#   validation loss:		5.791351
#   validation accuracy:		85.37 %
# Epoch 31 of 200 took 2.062s
#   training loss:		2.326470
#   validation loss:		5.840310
#   validation accuracy:		85.50 %
# Epoch 32 of 200 took 2.062s
#   training loss:		2.274973
#   validation loss:		6.053315
#   validation accuracy:		85.06 %
# Epoch 33 of 200 took 2.063s
#   training loss:		2.209052
#   validation loss:		5.970506
#   validation accuracy:		85.50 %
# Epoch 34 of 200 took 2.063s
#   training loss:		2.122870
#   validation loss:		6.509102
#   validation accuracy:		84.29 %
# Epoch 35 of 200 took 2.062s
#   training loss:		1.922150
#   validation loss:		6.067915
#   validation accuracy:		85.77 %
# Epoch 36 of 200 took 2.063s
#   training loss:		2.010064
#   validation loss:		6.083696
#   validation accuracy:		85.73 %
# Epoch 37 of 200 took 2.062s
#   training loss:		1.873788
#   validation loss:		5.981637
#   validation accuracy:		85.87 %
# Epoch 38 of 200 took 2.062s
#   training loss:		1.809799
#   validation loss:		5.969712
#   validation accuracy:		86.27 %
# Epoch 39 of 200 took 2.062s
#   training loss:		1.765215
#   validation loss:		5.858490
#   validation accuracy:		86.98 %
# Epoch 40 of 200 took 2.063s
#   training loss:		1.570150
#   validation loss:		6.751784
#   validation accuracy:		84.79 %
# Epoch 41 of 200 took 2.062s
#   training loss:		1.750262
#   validation loss:		5.790161
#   validation accuracy:		86.73 %
# Epoch 42 of 200 took 2.063s
#   training loss:		1.632207
#   validation loss:		5.901413
#   validation accuracy:		86.84 %
# Epoch 43 of 200 took 2.062s
#   training loss:		1.516518
#   validation loss:		5.885645
#   validation accuracy:		86.97 %
# Epoch 44 of 200 took 2.062s
#   training loss:		1.634088
#   validation loss:		6.378064
#   validation accuracy:		85.71 %
# Epoch 45 of 200 took 2.062s
#   training loss:		1.362537
#   validation loss:		6.218700
#   validation accuracy:		85.95 %
# Epoch 46 of 200 took 2.062s
#   training loss:		1.411855
#   validation loss:		6.563353
#   validation accuracy:		85.82 %
# Epoch 47 of 200 took 2.062s
#   training loss:		1.436640
#   validation loss:		6.075072
#   validation accuracy:		86.90 %
# Epoch 48 of 200 took 2.062s
#   training loss:		1.338309
#   validation loss:		6.019646
#   validation accuracy:		87.19 %
# Epoch 49 of 200 took 2.062s
#   training loss:		1.437924
#   validation loss:		5.884914
#   validation accuracy:		87.71 %
# Epoch 50 of 200 took 2.062s
#   training loss:		1.400007
#   validation loss:		6.060343
#   validation accuracy:		87.18 %
# Epoch 51 of 200 took 2.063s
#   training loss:		1.161521
#   validation loss:		6.655142
#   validation accuracy:		85.92 %
# Epoch 52 of 200 took 2.062s
#   training loss:		1.267420
#   validation loss:		5.937458
#   validation accuracy:		87.92 %
# Epoch 53 of 200 took 2.062s
#   training loss:		1.265028
#   validation loss:		6.136569
#   validation accuracy:		87.18 %
# Epoch 54 of 200 took 2.061s
#   training loss:		1.249923
#   validation loss:		5.954816
#   validation accuracy:		88.11 %
# Epoch 55 of 200 took 2.060s
#   training loss:		1.038891
#   validation loss:		6.608745
#   validation accuracy:		86.55 %
# Epoch 56 of 200 took 2.059s
#   training loss:		1.173874
#   validation loss:		6.947148
#   validation accuracy:		86.23 %
# Epoch 57 of 200 took 2.060s
#   training loss:		1.234070
#   validation loss:		6.340055
#   validation accuracy:		86.90 %
# Epoch 58 of 200 took 2.061s
#   training loss:		1.134503
#   validation loss:		6.087886
#   validation accuracy:		88.29 %
# Epoch 59 of 200 took 2.060s
#   training loss:		1.060920
#   validation loss:		6.633451
#   validation accuracy:		87.15 %
# Epoch 60 of 200 took 2.062s
#   training loss:		1.016291
#   validation loss:		6.915514
#   validation accuracy:		86.39 %
# Epoch 61 of 200 took 2.060s
#   training loss:		1.249611
#   validation loss:		6.246540
#   validation accuracy:		88.37 %
# Epoch 62 of 200 took 2.060s
#   training loss:		0.961605
#   validation loss:		6.943120
#   validation accuracy:		86.90 %
# Epoch 63 of 200 took 2.062s
#   training loss:		1.178566
#   validation loss:		6.418757
#   validation accuracy:		88.35 %
# Epoch 64 of 200 took 2.060s
#   training loss:		0.865588
#   validation loss:		6.615291
#   validation accuracy:		88.16 %
# Epoch 65 of 200 took 2.061s
#   training loss:		1.019069
#   validation loss:		6.580652
#   validation accuracy:		88.08 %
# Epoch 66 of 200 took 2.060s
#   training loss:		1.352371
#   validation loss:		6.487652
#   validation accuracy:		87.97 %
# Epoch 67 of 200 took 2.061s
#   training loss:		0.964285
#   validation loss:		6.737338
#   validation accuracy:		88.05 %
# Epoch 68 of 200 took 2.060s
#   training loss:		0.987818
#   validation loss:		6.633147
#   validation accuracy:		87.95 %
# Epoch 69 of 200 took 2.060s
#   training loss:		0.964028
#   validation loss:		6.807790
#   validation accuracy:		88.13 %
# Epoch 70 of 200 took 2.059s
#   training loss:		0.984069
#   validation loss:		6.740162
#   validation accuracy:		88.27 %
# Epoch 71 of 200 took 2.060s
#   training loss:		0.866246
#   validation loss:		6.981878
#   validation accuracy:		87.94 %
# Epoch 72 of 200 took 2.060s
#   training loss:		1.060633
#   validation loss:		7.711123
#   validation accuracy:		86.11 %
# Epoch 73 of 200 took 2.060s
#   training loss:		0.863778
#   validation loss:		6.998977
#   validation accuracy:		87.92 %
# Epoch 74 of 200 took 2.060s
#   training loss:		0.823845
#   validation loss:		7.052194
#   validation accuracy:		88.08 %
# Epoch 75 of 200 took 2.061s
#   training loss:		0.831223
#   validation loss:		7.203532
#   validation accuracy:		88.02 %
# Epoch 76 of 200 took 2.061s
#   training loss:		1.009745
#   validation loss:		7.114697
#   validation accuracy:		87.98 %
# Epoch 77 of 200 took 2.061s
#   training loss:		0.765449
#   validation loss:		7.033968
#   validation accuracy:		88.21 %
# Epoch 78 of 200 took 2.061s
#   training loss:		0.970587
#   validation loss:		6.945246
#   validation accuracy:		88.02 %
# Epoch 79 of 200 took 2.060s
#   training loss:		1.073379
#   validation loss:		7.156054
#   validation accuracy:		88.11 %
# Epoch 80 of 200 took 2.060s
#   training loss:		0.948588
#   validation loss:		7.242624
#   validation accuracy:		88.26 %
# Epoch 81 of 200 took 2.061s
#   training loss:		0.912148
#   validation loss:		7.139491
#   validation accuracy:		88.13 %
# Epoch 82 of 200 took 2.061s
#   training loss:		0.769188
#   validation loss:		7.280166
#   validation accuracy:		88.18 %
# Epoch 83 of 200 took 2.061s
#   training loss:		0.889828
#   validation loss:		7.294816
#   validation accuracy:		88.27 %
# Epoch 84 of 200 took 2.061s
#   training loss:		0.784748
#   validation loss:		14.285919
#   validation accuracy:		78.31 %
# Epoch 85 of 200 took 2.060s
#   training loss:		0.817790
#   validation loss:		7.926623
#   validation accuracy:		85.85 %
# Epoch 86 of 200 took 2.060s
#   training loss:		0.776349
#   validation loss:		7.614369
#   validation accuracy:		88.24 %
# Epoch 87 of 200 took 2.063s
#   training loss:		0.769516
#   validation loss:		7.558000
#   validation accuracy:		88.18 %
# Epoch 88 of 200 took 2.071s
#   training loss:		0.889629
#   validation loss:		7.370793
#   validation accuracy:		88.26 %
# Epoch 89 of 200 took 2.071s
#   training loss:		0.809513
#   validation loss:		7.370198
#   validation accuracy:		87.97 %
# Epoch 90 of 200 took 2.072s
#   training loss:		0.990169
#   validation loss:		7.265290
#   validation accuracy:		87.90 %
# Epoch 91 of 200 took 2.071s
#   training loss:		0.627627
#   validation loss:		7.398189
#   validation accuracy:		88.34 %
# Epoch 92 of 200 took 2.071s
#   training loss:		0.760234
#   validation loss:		7.411252
#   validation accuracy:		88.48 %
# Epoch 93 of 200 took 2.071s
#   training loss:		0.725941
#   validation loss:		7.395885
#   validation accuracy:		88.26 %
# Epoch 94 of 200 took 2.071s
#   training loss:		0.667666
#   validation loss:		7.601581
#   validation accuracy:		87.85 %
# Epoch 95 of 200 took 2.071s
#   training loss:		0.776467
#   validation loss:		7.481466
#   validation accuracy:		88.48 %
# Epoch 96 of 200 took 2.073s
#   training loss:		0.805260
#   validation loss:		8.066114
#   validation accuracy:		87.24 %
# Epoch 97 of 200 took 2.071s
#   training loss:		0.692767
#   validation loss:		7.555827
#   validation accuracy:		88.55 %
# Epoch 98 of 200 took 2.071s
#   training loss:		0.657079
#   validation loss:		7.643262
#   validation accuracy:		88.34 %
# Epoch 99 of 200 took 2.072s
#   training loss:		0.674793
#   validation loss:		7.863648
#   validation accuracy:		88.35 %
# Epoch 100 of 200 took 2.072s
#   training loss:		0.762698
#   validation loss:		8.122838
#   validation accuracy:		87.52 %
# Epoch 101 of 200 took 2.072s
#   training loss:		0.645608
#   validation loss:		7.637064
#   validation accuracy:		88.34 %
# Epoch 102 of 200 took 2.072s
#   training loss:		0.873223
#   validation loss:		7.692471
#   validation accuracy:		88.37 %
# Epoch 103 of 200 took 2.072s
#   training loss:		0.663715
#   validation loss:		8.693218
#   validation accuracy:		86.48 %
# Epoch 104 of 200 took 2.072s
#   training loss:		0.690002
#   validation loss:		7.985356
#   validation accuracy:		88.08 %
# Epoch 105 of 200 took 2.073s
#   training loss:		0.698779
#   validation loss:		7.907662
#   validation accuracy:		88.15 %
# Epoch 106 of 200 took 2.071s
#   training loss:		0.718878
#   validation loss:		7.747598
#   validation accuracy:		88.37 %
# Epoch 107 of 200 took 2.072s
#   training loss:		0.606577
#   validation loss:		7.898219
#   validation accuracy:		88.40 %
# Epoch 108 of 200 took 2.072s
#   training loss:		0.753330
#   validation loss:		8.183240
#   validation accuracy:		88.19 %
# Epoch 109 of 200 took 2.072s
#   training loss:		0.611265
#   validation loss:		8.181118
#   validation accuracy:		88.19 %
# Epoch 110 of 200 took 2.072s
#   training loss:		0.647711
#   validation loss:		8.392745
#   validation accuracy:		87.68 %
# Epoch 111 of 200 took 2.072s
#   training loss:		0.826520
#   validation loss:		8.144990
#   validation accuracy:		87.94 %
# Epoch 112 of 200 took 2.072s
#   training loss:		0.604380
#   validation loss:		8.122108
#   validation accuracy:		88.34 %
# Epoch 113 of 200 took 2.072s
#   training loss:		0.756185
#   validation loss:		8.339684
#   validation accuracy:		87.82 %
# Epoch 114 of 200 took 2.073s
#   training loss:		0.562081
#   validation loss:		7.884141
#   validation accuracy:		88.69 %
# Epoch 115 of 200 took 2.072s
#   training loss:		1.003342
#   validation loss:		7.792594
#   validation accuracy:		88.50 %
# Epoch 116 of 200 took 2.073s
#   training loss:		0.768255
#   validation loss:		7.709007
#   validation accuracy:		88.89 %
# Epoch 117 of 200 took 2.074s
#   training loss:		0.634880
#   validation loss:		7.880560
#   validation accuracy:		88.82 %
# Epoch 118 of 200 took 2.072s
#   training loss:		0.644543
#   validation loss:		8.230515
#   validation accuracy:		88.23 %
# Epoch 119 of 200 took 2.072s
#   training loss:		0.583857
#   validation loss:		8.334500
#   validation accuracy:		87.85 %
# Epoch 120 of 200 took 2.073s
#   training loss:		0.645938
#   validation loss:		8.225623
#   validation accuracy:		88.48 %
# Epoch 121 of 200 took 2.072s
#   training loss:		0.640889
#   validation loss:		8.076601
#   validation accuracy:		88.55 %
# Epoch 122 of 200 took 2.072s
#   training loss:		0.811224
#   validation loss:		7.977906
#   validation accuracy:		88.55 %
# Epoch 123 of 200 took 2.074s
#   training loss:		0.671817
#   validation loss:		8.742683
#   validation accuracy:		88.08 %
# Epoch 124 of 200 took 2.072s
#   training loss:		0.573144
#   validation loss:		8.376369
#   validation accuracy:		88.16 %
# Epoch 125 of 200 took 2.073s
#   training loss:		0.681373
#   validation loss:		8.498024
#   validation accuracy:		88.29 %
# Epoch 126 of 200 took 2.074s
#   training loss:		0.653643
#   validation loss:		8.671869
#   validation accuracy:		87.87 %
# Epoch 127 of 200 took 2.072s
#   training loss:		0.610891
#   validation loss:		8.537639
#   validation accuracy:		88.35 %
# Epoch 128 of 200 took 2.073s
#   training loss:		0.663975
#   validation loss:		8.489100
#   validation accuracy:		88.37 %
# Epoch 129 of 200 took 2.075s
#   training loss:		0.604207
#   validation loss:		8.420615
#   validation accuracy:		88.47 %
# Epoch 130 of 200 took 2.073s
#   training loss:		0.557852
#   validation loss:		8.399234
#   validation accuracy:		88.48 %
# Epoch 131 of 200 took 2.072s
#   training loss:		0.685311
#   validation loss:		8.624429
#   validation accuracy:		87.60 %
# Epoch 132 of 200 took 2.074s
#   training loss:		0.676567
#   validation loss:		8.991221
#   validation accuracy:		86.29 %
# Epoch 133 of 200 took 2.072s
#   training loss:		0.546557
#   validation loss:		8.730358
#   validation accuracy:		87.85 %
# Epoch 134 of 200 took 2.072s
#   training loss:		0.586699
#   validation loss:		8.530909
#   validation accuracy:		87.87 %
# Epoch 135 of 200 took 2.073s
#   training loss:		0.671651
#   validation loss:		8.351881
#   validation accuracy:		88.48 %
# Epoch 136 of 200 took 2.072s
#   training loss:		0.641052
#   validation loss:		8.103724
#   validation accuracy:		88.73 %
# Epoch 137 of 200 took 2.074s
#   training loss:		0.553226
#   validation loss:		8.617248
#   validation accuracy:		88.56 %
# Epoch 138 of 200 took 2.074s
#   training loss:		0.567471
#   validation loss:		8.604216
#   validation accuracy:		88.18 %
# Epoch 139 of 200 took 2.074s
#   training loss:		0.601868
#   validation loss:		8.358653
#   validation accuracy:		88.48 %
# Epoch 140 of 200 took 2.073s
#   training loss:		0.589133
#   validation loss:		8.651493
#   validation accuracy:		88.37 %
# Epoch 141 of 200 took 2.075s
#   training loss:		0.584859
#   validation loss:		8.385245
#   validation accuracy:		88.74 %
# Epoch 142 of 200 took 2.073s
#   training loss:		0.550761
#   validation loss:		8.936479
#   validation accuracy:		88.44 %
# Epoch 143 of 200 took 2.073s
#   training loss:		0.621321
#   validation loss:		8.848597
#   validation accuracy:		88.44 %
# Epoch 144 of 200 took 2.074s
#   training loss:		0.579086
#   validation loss:		8.425350
#   validation accuracy:		88.94 %
# Epoch 145 of 200 took 2.074s
#   training loss:		0.593112
#   validation loss:		8.869738
#   validation accuracy:		88.19 %
# Epoch 146 of 200 took 2.073s
#   training loss:		0.566549
#   validation loss:		8.598150
#   validation accuracy:		88.56 %
# Epoch 147 of 200 took 2.074s
#   training loss:		0.844377
#   validation loss:		8.449852
#   validation accuracy:		88.85 %
# Epoch 148 of 200 took 2.073s
#   training loss:		0.503898
#   validation loss:		10.954621
#   validation accuracy:		85.50 %
# Epoch 149 of 200 took 2.073s
#   training loss:		0.613184
#   validation loss:		9.087348
#   validation accuracy:		88.55 %
# Epoch 150 of 200 took 2.075s
#   training loss:		0.635622
#   validation loss:		8.614345
#   validation accuracy:		88.87 %
# Epoch 151 of 200 took 2.073s
#   training loss:		0.489067
#   validation loss:		8.626352
#   validation accuracy:		88.74 %
# Epoch 152 of 200 took 2.074s
#   training loss:		0.733472
#   validation loss:		8.769215
#   validation accuracy:		88.21 %
# Epoch 153 of 200 took 2.073s
#   training loss:		0.548964
#   validation loss:		8.515185
#   validation accuracy:		88.47 %
# Epoch 154 of 200 took 2.073s
#   training loss:		0.646860
#   validation loss:		8.863407
#   validation accuracy:		88.66 %
# Epoch 155 of 200 took 2.073s
#   training loss:		0.579578
#   validation loss:		9.246329
#   validation accuracy:		87.79 %
# Epoch 156 of 200 took 2.073s
#   training loss:		0.643507
#   validation loss:		8.646564
#   validation accuracy:		88.29 %
# Epoch 157 of 200 took 2.075s
#   training loss:		0.467432
#   validation loss:		9.477703
#   validation accuracy:		87.87 %
# Epoch 158 of 200 took 2.074s
#   training loss:		0.914235
#   validation loss:		8.992857
#   validation accuracy:		88.44 %
# Epoch 159 of 200 took 2.075s
#   training loss:		0.621518
#   validation loss:		8.945880
#   validation accuracy:		88.79 %
# Epoch 160 of 200 took 2.074s
#   training loss:		0.689412
#   validation loss:		8.802355
#   validation accuracy:		88.66 %
# Epoch 161 of 200 took 2.074s
#   training loss:		0.473427
#   validation loss:		9.912748
#   validation accuracy:		86.73 %
# Epoch 162 of 200 took 2.075s
#   training loss:		0.869257
#   validation loss:		8.947633
#   validation accuracy:		88.53 %
# Epoch 163 of 200 took 2.073s
#   training loss:		0.615326
#   validation loss:		8.516956
#   validation accuracy:		88.58 %
# Epoch 164 of 200 took 2.074s
#   training loss:		0.536484
#   validation loss:		8.961707
#   validation accuracy:		88.66 %
# Epoch 165 of 200 took 2.074s
#   training loss:		0.540885
#   validation loss:		9.008512
#   validation accuracy:		88.61 %
# Epoch 166 of 200 took 2.075s
#   training loss:		0.605501
#   validation loss:		8.847777
#   validation accuracy:		88.73 %
# Epoch 167 of 200 took 2.074s
#   training loss:		0.489774
#   validation loss:		8.919621
#   validation accuracy:		88.82 %
# Epoch 168 of 200 took 2.075s
#   training loss:		0.504762
#   validation loss:		9.505160
#   validation accuracy:		87.95 %
# Epoch 169 of 200 took 2.074s
#   training loss:		0.581676
#   validation loss:		9.251140
#   validation accuracy:		88.02 %
# Epoch 170 of 200 took 2.074s
#   training loss:		0.513256
#   validation loss:		8.937922
#   validation accuracy:		88.60 %
# Epoch 171 of 200 took 2.074s
#   training loss:		0.538741
#   validation loss:		8.869882
#   validation accuracy:		88.82 %
# Epoch 172 of 200 took 2.074s
#   training loss:		0.516145
#   validation loss:		8.926565
#   validation accuracy:		88.65 %
# Epoch 173 of 200 took 2.074s
#   training loss:		0.502596
#   validation loss:		8.911150
#   validation accuracy:		88.90 %
# Epoch 174 of 200 took 2.075s
#   training loss:		0.498114
#   validation loss:		8.905230
#   validation accuracy:		88.82 %
# Epoch 175 of 200 took 2.074s
#   training loss:		0.968115
#   validation loss:		8.906946
#   validation accuracy:		88.69 %
# Epoch 176 of 200 took 2.074s
#   training loss:		0.602605
#   validation loss:		9.008019
#   validation accuracy:		88.58 %
# Epoch 177 of 200 took 2.076s
#   training loss:		0.464189
#   validation loss:		9.015907
#   validation accuracy:		88.79 %
# Epoch 178 of 200 took 2.075s
#   training loss:		0.497435
#   validation loss:		8.960773
#   validation accuracy:		88.77 %
# Epoch 179 of 200 took 2.074s
#   training loss:		0.503739
#   validation loss:		9.065078
#   validation accuracy:		88.48 %
# Epoch 180 of 200 took 2.076s
#   training loss:		0.616651
#   validation loss:		8.933717
#   validation accuracy:		88.60 %
# Epoch 181 of 200 took 2.075s
#   training loss:		0.459695
#   validation loss:		9.398473
#   validation accuracy:		88.13 %
# Epoch 182 of 200 took 2.075s
#   training loss:		0.522442
#   validation loss:		9.724314
#   validation accuracy:		87.87 %
# Epoch 183 of 200 took 2.076s
#   training loss:		0.538323
#   validation loss:		9.531887
#   validation accuracy:		88.63 %
# Epoch 184 of 200 took 2.075s
#   training loss:		0.721546
#   validation loss:		9.288372
#   validation accuracy:		88.76 %
# Epoch 185 of 200 took 2.074s
#   training loss:		0.452954
#   validation loss:		9.444899
#   validation accuracy:		88.53 %
# Epoch 186 of 200 took 2.076s
#   training loss:		0.550424
#   validation loss:		9.389391
#   validation accuracy:		88.27 %
# Epoch 187 of 200 took 2.074s
#   training loss:		0.555409
#   validation loss:		9.375278
#   validation accuracy:		88.60 %
# Epoch 188 of 200 took 2.074s
#   training loss:		0.502929
#   validation loss:		9.495005
#   validation accuracy:		88.58 %
# Epoch 189 of 200 took 2.074s
#   training loss:		0.649856
#   validation loss:		9.401355
#   validation accuracy:		88.50 %
# Epoch 190 of 200 took 2.074s
#   training loss:		0.548730
#   validation loss:		9.834577
#   validation accuracy:		87.55 %
# Epoch 191 of 200 took 2.075s
#   training loss:		0.463709
#   validation loss:		9.674107
#   validation accuracy:		88.02 %
# Epoch 192 of 200 took 2.076s
#   training loss:		0.530177
#   validation loss:		9.664849
#   validation accuracy:		88.61 %
# Epoch 193 of 200 took 2.076s
#   training loss:		0.563368
#   validation loss:		9.878466
#   validation accuracy:		88.24 %
# Epoch 194 of 200 took 2.079s
#   training loss:		0.500827
#   validation loss:		9.394641
#   validation accuracy:		88.68 %
# Epoch 195 of 200 took 2.077s
#   training loss:		0.459576
#   validation loss:		9.381795
#   validation accuracy:		88.65 %
# Epoch 196 of 200 took 2.075s
#   training loss:		0.557288
#   validation loss:		9.501820
#   validation accuracy:		88.74 %
# Epoch 197 of 200 took 2.076s
#   training loss:		0.560924
#   validation loss:		9.493920
#   validation accuracy:		88.81 %
# Epoch 198 of 200 took 2.077s
#   training loss:		0.473677
#   validation loss:		9.675714
#   validation accuracy:		88.50 %
# Epoch 199 of 200 took 2.075s
#   training loss:		0.480261
#   validation loss:		9.857995
#   validation accuracy:		88.32 %
# Epoch 200 of 200 took 2.074s
#   training loss:		0.485180
#   validation loss:		9.676435
#   validation accuracy:		88.89 %

# %% [markdown]
# Now let's create a function that computes the latent representation variables z so we can visualize them on the test set.

# %%
z = nn.layers.get_output(l_latent)

compute_z = theano.function(
    [], z,
    givens={
        x: dataset['X_test'],
    },
)

z_vals = compute_z()

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(z_vals[:, 0], z_vals[:, 1], alpha=0.1)
plt.show()

# %% [markdown]
# This corresponds to figure 4a in the paper. Our latent variables have a smaller magnitude overall, but exhibit a roughly Gaussian distribution just like in the paper.
#
# Now let's generate some reconstructions. Our aim is to reproduce figures 4b and 4c. We'll need to compile a function that allows us to set the desired values for the latent variables `y` and `z`.
#
# Lasagne makes it possible to map any layer in the network to a custom expression by supplying a dictionary to `nn.layers.get_output()`. We'll make use of this to 'clamp' the observed and latent representation variables.

# %%
y_clamped = T.ivector('y_clamped')
z_clamped = T.matrix('z_clamped')

x_recon = nn.layers.get_output(l_decoder_out, {
        l_observed: nn.utils.one_hot(y_clamped, m=dataset["output_dim"]),
        l_latent: z_clamped,
    })

reconstruct = theano.function([y_clamped, z_clamped], x_recon)

# %%
R = 2
ys = np.repeat(np.arange(dataset["output_dim"]), R).astype('int32')
zs = np.tile(np.linspace(-0.5, 0.5, R), dataset["output_dim"]).astype(theano.config.floatX)
z1s = np.vstack([zs, np.zeros_like(zs)]).T
z2s = np.vstack([np.zeros_like(zs), zs]).T

# %%
reconstructions_z1 = reconstruct(ys, z1s)
reconstructions_z2 = reconstruct(ys, z2s)

# %%
im1 = reconstructions_z1.reshape(dataset["output_dim"], R, w, h).transpose(1, 2, 0, 3).reshape(R * w, dataset["output_dim"] * h)
plt.imshow(im1, cmap=plt.cm.gray)
plt.show()

# %%
im2 = reconstructions_z2.reshape(dataset["output_dim"], 9, w, h).transpose(1, 2, 0, 3).reshape(9 * w, dataset["output_dim"] * h)
plt.imshow(im2, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# The reconstructions show some interesting structure as `z1` and `z2` are varied. Pretty cool!

# %%
reconstructions_z1.shape
for i in range(reconstructions_z1.shape[0]):
    plt.clf()
    plt.imshow(reconstructions_z1[i].reshape((64, 64)), cmap="gray")
    plt.show()
