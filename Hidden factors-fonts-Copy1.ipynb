# %% [markdown]
# # Discovering hidden factors of variation in deep networks
#
# **This is an example of how to implement the autoencoder architecture from [Cheung et al. (2014)](http://arxiv.org/abs/1412.6583) in Lasagne.** This uses the code from the MNIST example bundled with Lasagne, so you will need to have the `mnist.py` file available for importing.

# %%
# %matplotlib inline
import os
os.environ["THEANO_FLAGS"]= "device=gpu1"

# %%
import numpy as np
import theano
import theano.tensor as T
import lasagne as nn
w, h = 64, 64
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# Using gpu device 1: Tesla K20m

# %%
from skimage.transform import resize
from skimage.filter import threshold_otsu

def binarize(X):
    X_b = np.empty(X.shape, dtype=X.dtype)
    for i in range(X.shape[0]):
        X_b[i] = 1. * (X[i] <= threshold_otsu(X[i]))
    return X_b

def resize_all(X, w, h):
    if X.shape[1] == w and X.shape[2] == h:
        return X
    X_b = np.empty((X.shape[0], w, h), dtype=X.dtype)
    for i in range(X.shape[0]):
        X_b[i] = resize(X[i], (w, h))
    return X_b

# %% [markdown]
# **We'll define the model listed in the first column of Table 1 in the paper.**
#
# This model has an encoder with two ReLU layers. In the paper they both have 500 units but we'll make this configurable so we can speed up the experiment a bit if necessary.
#
# On top of the encoder are two representation layers: one is a 10-way softmax layer which represents the class of the input. This is the observed representation layer. Then there is also a latent representation layer which has two additional linear units (the authors use only two units for easy visualization).
#
# Both representation layers are concatenated and the decoder is stacked on top. This consists of three layers: two hidden ReLU layers with again 500 units, and finally a linear reconstruction layer with 784 outputs.

# %%
def build_model(input_dim, output_dim, batch_size,
                num_hidden_units=500):
    l_in = nn.layers.InputLayer((batch_size, input_dim))
    
    # encoder
    l_encoder1 = nn.layers.DenseLayer(l_in, num_units=num_hidden_units)
    l_encoder2 = nn.layers.DenseLayer(l_encoder1, num_units=num_hidden_units)
    l_encoder3 = nn.layers.DenseLayer(l_encoder2, num_units=num_hidden_units)
    l_encoder4 = nn.layers.DenseLayer(l_encoder3, num_units=num_hidden_units)
    
    # learned representation
    l_observed = nn.layers.DenseLayer(l_encoder4, num_units=output_dim,
                                      nonlinearity=T.nnet.softmax)
    
    l_latent = nn.layers.DenseLayer(l_encoder4, 
                                    num_units=30,
                                    nonlinearity=None) # linear
    
    l_representation = nn.layers.concat([l_observed, l_latent])
    
    # decoder
    l_decoder1 = nn.layers.DenseLayer(l_representation, num_units=num_hidden_units)
    l_decoder2 = nn.layers.DenseLayer(l_decoder1, num_units=num_hidden_units)
    l_decoder3 = nn.layers.DenseLayer(l_decoder2, num_units=num_hidden_units)
    l_decoder4 = nn.layers.DenseLayer(l_decoder3, num_units=num_hidden_units)
    l_decoder_out = nn.layers.DenseLayer(l_decoder4, num_units=input_dim,
                                       nonlinearity=nonlinearities.sigmoid)
    
    return l_in, l_decoder_out, l_observed, l_latent

# %% [markdown]
# Next, **we'll define the cost function**. This consists of three parts: `alpha * U + beta * S + gamma * C` (formula 3 in the paper). `U` is the reconstruction cost, `S` is the supervised cost and `C` is the so-called "XCov" cost which disentangles the observed and latent variables of the encoder.

# %%
def cost(x, y, x_recon, y_pred, z, alpha=1.0, beta=10.0, gamma=10.0):
    """
    x, y: the input and the corresponding label
    x_recon: the model reconstruction of the input
    y_pred: the model prediction (observed variables)
    z: the latent variables
    """
    # reconstruction cost: mean squared error
    U = ((x - x_recon)**2).mean()
    
    # supervised cost: categorical cross-entropy
    S = T.mean(T.nnet.categorical_crossentropy(y_pred, y))
    
    # XCov cost: cross-covariance
    y_pred_mean = T.mean(y_pred, axis=0, keepdims=True)
    z_mean = T.mean(z, axis=0, keepdims=True)
    y_pred_centered = y_pred - y_pred_mean # (n, i)
    z_centered = z - z_mean # (n, j)
    
    outer_prod = (y_pred_centered.dimshuffle(0, 1, 'x') *
                  z_centered.dimshuffle(0, 'x', 1)) # (n, i, j)
    C = 0.5 * T.sum(T.sqr(T.mean(outer_prod, axis=0)))
    
    # the total cost is a weighted sum
    return alpha * U + beta * S + gamma * C

# %%
from lasagne.datasets.mnist import MNIST
from sklearn.cross_validation import train_test_split
import lasagne.easy

def load_data():
    """Get data with labels, split into training, validation and test set."""
    from lasagne.datasets.fonts import Fonts
    
    data = Fonts(kind="all_64",
                 labels_kind="letters")
    data.load()
    
    #data = MNIST()
    #data.load()
    
    X = data.X
    #X = X.reshape((X.shape[0], 28, 28))
    #X = resize_all(X, w, h)
    
    #X = binarize(X)
    X = 1 - X
    X = X.astype(np.float32)
    X = X.reshape((X.shape[0], w*h))
    y = data.y
    X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.25)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.25)
    
    return dict(
        X_train=theano.shared(lasagne.utils.floatX(X_train)),
        y_train=T.cast(theano.shared(y_train), 'int32'),
        X_valid=theano.shared(lasagne.utils.floatX(X_valid)),
        y_valid=T.cast(theano.shared(y_valid), 'int32'),
        X_test=theano.shared(lasagne.utils.floatX(X_test)),
        y_test=T.cast(theano.shared(y_test), 'int32'),
        num_examples_train=X_train.shape[0],
        num_examples_valid=X_valid.shape[0],
        num_examples_test=X_test.shape[0],
        input_dim=X_train.shape[1],
        output_dim=len(set(y)),
    )

# %% [markdown]
# Now let's tie everything together in the main training loop.

# %%
from mnist import train
import time

num_epochs = 200
batch_size = 100

print("Loading data...")
dataset = load_data()
print(dataset.keys())
# Out:
# Loading data...
# ['X_test', 'num_examples_train', 'X_train', 'num_examples_valid', 'num_examples_test', 'output_dim', 'X_valid', 'y_valid', 'y_train', 'input_dim', 'y_test']

# %%
import matplotlib.pyplot as plt
plt.imshow(dataset["X_train"].get_value()[12].reshape((64, 64)), cmap="gray")

# %%
print("Building model and compiling functions...")
l_in, l_decoder_out, l_observed, l_latent = build_model(
    input_dim=dataset['input_dim'],
    output_dim=dataset['output_dim'],
    batch_size=batch_size,
)

x = l_in.input_var
y = T.ivector('y')
x_recon, y_pred, z = nn.layers.get_output([l_decoder_out, l_observed, l_latent])
# Note that we call get_output() once to get all the model outputs.
# This is to guarantee they are consistent and share computations where
# possible. When the network contains nondeterminism (such as dropout
# regularization), guaranteeing this consistency is crucially important.
loss = cost(x, y, x_recon, y_pred, z, gamma=0, alpha=1, beta=1)
params = nn.layers.get_all_params(l_decoder_out)

# # add some L2 regularization
# params_reg = nn.layers.get_all_params(l_decoder_out, regularizable=True)
# reg = sum(T.sum(p**2) for p in params_reg)
# loss += 0.01 * reg

# The authors mention that they use adadelta, let's do the same
updates = nn.updates.adadelta(loss, params, learning_rate=0.1)

# compile iteration functions
batch_index = T.iscalar('batch_index')
batch_slice = slice(batch_index * batch_size,
                    (batch_index + 1) * batch_size)

pred = T.argmax(y_pred, axis=1)
accuracy = T.mean(T.eq(pred, y), dtype=theano.config.floatX)

iter_train = theano.function(
    [batch_index], loss,
    updates=updates,
    givens={
        x: dataset['X_train'][batch_slice],
        y: dataset['y_train'][batch_slice],
    },
)

iter_valid = theano.function(
    [batch_index], [loss, accuracy],
    givens={
        x: dataset['X_valid'][batch_slice],
        y: dataset['y_valid'][batch_slice],
    },
)

iter_test = theano.function(
    [batch_index], [loss, accuracy],
    givens={
        x: dataset['X_test'][batch_slice],
        y: dataset['y_test'][batch_slice],
    },
)

iter_funcs =  dict(
    train=iter_train,
    valid=iter_valid,
    test=iter_test,
)

print("Starting training...")
now = time.time()
try:
    for epoch in train(iter_funcs, dataset, batch_size=batch_size):
        print("Epoch {} of {} took {:.3f}s".format(
            epoch['number'], num_epochs, time.time() - now))
        now = time.time()
        print("  training loss:\t\t{:.6f}".format(epoch['train_loss']))
        print("  validation loss:\t\t{:.6f}".format(epoch['valid_loss']))
        
        print("  validation accuracy:\t\t{:.2f} %".format(
            epoch['valid_accuracy'] * 100))

        if epoch['number'] >= num_epochs:
            break

except KeyboardInterrupt:
    pass
# Out:
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 200 took 2.528s
#   training loss:		1.610391
#   validation loss:		1.028153
#   validation accuracy:		75.82 %
# Epoch 2 of 200 took 2.528s
#   training loss:		0.858895
#   validation loss:		0.851146
#   validation accuracy:		79.85 %
# Epoch 3 of 200 took 2.527s
#   training loss:		0.679411
#   validation loss:		0.747176
#   validation accuracy:		82.15 %
# Epoch 4 of 200 took 2.527s
#   training loss:		0.553454
#   validation loss:		0.652596
#   validation accuracy:		84.73 %
# Epoch 5 of 200 took 2.527s
#   training loss:		0.461941
#   validation loss:		0.593165
#   validation accuracy:		85.95 %
# Epoch 6 of 200 took 2.527s
#   training loss:		0.392004
#   validation loss:		0.571605
#   validation accuracy:		86.63 %
# Epoch 7 of 200 took 2.526s
#   training loss:		0.337243
#   validation loss:		0.561482
#   validation accuracy:		86.92 %
# Epoch 8 of 200 took 2.527s
#   training loss:		0.293205
#   validation loss:		0.557880
#   validation accuracy:		87.35 %
# Epoch 9 of 200 took 2.527s
#   training loss:		0.255727
#   validation loss:		0.573822
#   validation accuracy:		87.02 %
# Epoch 10 of 200 took 2.526s
#   training loss:		0.228346
#   validation loss:		0.577025
#   validation accuracy:		87.34 %
# Epoch 11 of 200 took 2.526s
#   training loss:		0.213356
#   validation loss:		0.574106
#   validation accuracy:		87.69 %
# Epoch 12 of 200 took 2.526s
#   training loss:		0.185522
#   validation loss:		0.573179
#   validation accuracy:		87.98 %
# Epoch 13 of 200 took 2.526s
#   training loss:		0.168187
#   validation loss:		0.579415
#   validation accuracy:		88.26 %
# Epoch 14 of 200 took 2.526s
#   training loss:		0.163438
#   validation loss:		0.571290
#   validation accuracy:		88.71 %
# Epoch 15 of 200 took 2.526s
#   training loss:		0.154422
#   validation loss:		0.595722
#   validation accuracy:		88.34 %
# Epoch 16 of 200 took 2.526s
#   training loss:		0.144608
#   validation loss:		0.617939
#   validation accuracy:		88.27 %
# Epoch 17 of 200 took 2.526s
#   training loss:		0.133921
#   validation loss:		0.628409
#   validation accuracy:		88.18 %
# Epoch 18 of 200 took 2.527s
#   training loss:		0.129174
#   validation loss:		0.639192
#   validation accuracy:		88.42 %
# Epoch 19 of 200 took 2.526s
#   training loss:		0.125618
#   validation loss:		0.650374
#   validation accuracy:		88.26 %
# Epoch 20 of 200 took 2.526s
#   training loss:		0.137283
#   validation loss:		0.631902
#   validation accuracy:		88.44 %
# Epoch 21 of 200 took 2.527s
#   training loss:		0.120879
#   validation loss:		0.652143
#   validation accuracy:		88.74 %
# Epoch 22 of 200 took 2.527s
#   training loss:		0.118883
#   validation loss:		0.668411
#   validation accuracy:		88.76 %
# Epoch 23 of 200 took 2.526s
#   training loss:		0.115674
#   validation loss:		0.675680
#   validation accuracy:		88.56 %
# Epoch 24 of 200 took 2.527s
#   training loss:		0.113492
#   validation loss:		0.684281
#   validation accuracy:		88.85 %
# Epoch 25 of 200 took 2.527s
#   training loss:		0.112885
#   validation loss:		0.707322
#   validation accuracy:		88.40 %
# Epoch 26 of 200 took 2.526s
#   training loss:		0.110943
#   validation loss:		0.713833
#   validation accuracy:		88.31 %
# Epoch 27 of 200 took 2.527s
#   training loss:		0.109817
#   validation loss:		0.736832
#   validation accuracy:		87.98 %
# Epoch 28 of 200 took 2.527s
#   training loss:		0.108337
#   validation loss:		0.739396
#   validation accuracy:		88.06 %
# Epoch 29 of 200 took 2.527s
#   training loss:		0.121728
#   validation loss:		0.704741
#   validation accuracy:		88.61 %
# Epoch 30 of 200 took 2.527s
#   training loss:		0.111924
#   validation loss:		0.691182
#   validation accuracy:		88.68 %
# Epoch 31 of 200 took 2.527s
#   training loss:		0.106821
#   validation loss:		0.741568
#   validation accuracy:		88.19 %
# Epoch 32 of 200 took 2.526s
#   training loss:		0.106278
#   validation loss:		0.753607
#   validation accuracy:		88.05 %
# Epoch 33 of 200 took 2.527s
#   training loss:		0.104641
#   validation loss:		0.762795
#   validation accuracy:		87.95 %
# Epoch 34 of 200 took 2.527s
#   training loss:		0.105042
#   validation loss:		0.772646
#   validation accuracy:		88.03 %
# Epoch 35 of 200 took 2.526s
#   training loss:		0.103037
#   validation loss:		0.766743
#   validation accuracy:		87.87 %
# Epoch 36 of 200 took 2.527s
#   training loss:		0.104105
#   validation loss:		0.761622
#   validation accuracy:		87.81 %
# Epoch 37 of 200 took 2.527s
#   training loss:		0.103569
#   validation loss:		0.686775
#   validation accuracy:		89.18 %
# Epoch 38 of 200 took 2.526s
#   training loss:		0.101222
#   validation loss:		0.686885
#   validation accuracy:		89.11 %
# Epoch 39 of 200 took 2.527s
#   training loss:		0.100101
#   validation loss:		0.690218
#   validation accuracy:		89.32 %
# Epoch 40 of 200 took 2.527s
#   training loss:		0.099231
#   validation loss:		0.698024
#   validation accuracy:		89.29 %
# Epoch 41 of 200 took 2.527s
#   training loss:		0.099229
#   validation loss:		0.699346
#   validation accuracy:		89.29 %
# Epoch 42 of 200 took 2.527s
#   training loss:		0.099422
#   validation loss:		0.701348
#   validation accuracy:		89.24 %
# Epoch 43 of 200 took 2.527s
#   training loss:		0.098260
#   validation loss:		0.705438
#   validation accuracy:		89.19 %
# Epoch 44 of 200 took 2.527s
#   training loss:		0.097519
#   validation loss:		0.712896
#   validation accuracy:		89.31 %
# Epoch 45 of 200 took 2.527s
#   training loss:		0.097151
#   validation loss:		0.711331
#   validation accuracy:		89.27 %
# Epoch 46 of 200 took 2.528s
#   training loss:		0.096854
#   validation loss:		0.713283
#   validation accuracy:		89.19 %
# Epoch 47 of 200 took 2.527s
#   training loss:		0.096308
#   validation loss:		0.715161
#   validation accuracy:		89.15 %
# Epoch 48 of 200 took 2.527s
#   training loss:		0.095866
#   validation loss:		0.720997
#   validation accuracy:		89.19 %
# Epoch 49 of 200 took 2.528s
#   training loss:		0.095138
#   validation loss:		0.717255
#   validation accuracy:		89.13 %
# Epoch 50 of 200 took 2.528s
#   training loss:		0.094844
#   validation loss:		0.718689
#   validation accuracy:		89.06 %
# Epoch 51 of 200 took 2.528s
#   training loss:		0.094110
#   validation loss:		0.720064
#   validation accuracy:		89.10 %
# Epoch 52 of 200 took 2.528s
#   training loss:		0.094339
#   validation loss:		0.718234
#   validation accuracy:		89.10 %
# Epoch 53 of 200 took 2.527s
#   training loss:		0.093503
#   validation loss:		0.722888
#   validation accuracy:		89.13 %
# Epoch 54 of 200 took 2.528s
#   training loss:		0.093002
#   validation loss:		0.733043
#   validation accuracy:		88.98 %
# Epoch 55 of 200 took 2.527s
#   training loss:		0.093217
#   validation loss:		0.725476
#   validation accuracy:		89.15 %
# Epoch 56 of 200 took 2.527s
#   training loss:		0.092741
#   validation loss:		0.726988
#   validation accuracy:		89.08 %
# Epoch 57 of 200 took 2.528s
#   training loss:		0.091927
#   validation loss:		0.730655
#   validation accuracy:		89.08 %
# Epoch 58 of 200 took 2.529s
#   training loss:		0.092317
#   validation loss:		0.726484
#   validation accuracy:		89.03 %
# Epoch 59 of 200 took 2.528s
#   training loss:		0.091249
#   validation loss:		0.736491
#   validation accuracy:		89.06 %
# Epoch 60 of 200 took 2.527s
#   training loss:		0.090914
#   validation loss:		0.747624
#   validation accuracy:		89.10 %
# Epoch 61 of 200 took 2.528s
#   training loss:		0.091313
#   validation loss:		0.741584
#   validation accuracy:		89.13 %
# Epoch 62 of 200 took 2.528s
#   training loss:		0.090883
#   validation loss:		0.742455
#   validation accuracy:		89.11 %
# Epoch 63 of 200 took 2.528s
#   training loss:		0.090505
#   validation loss:		0.742011
#   validation accuracy:		89.16 %
# Epoch 64 of 200 took 2.529s
#   training loss:		0.090102
#   validation loss:		0.742896
#   validation accuracy:		89.27 %
# Epoch 65 of 200 took 2.528s
#   training loss:		0.089905
#   validation loss:		0.739093
#   validation accuracy:		89.21 %
# Epoch 66 of 200 took 2.528s
#   training loss:		0.090026
#   validation loss:		0.729715
#   validation accuracy:		89.15 %
# Epoch 67 of 200 took 2.528s
#   training loss:		0.089453
#   validation loss:		0.731753
#   validation accuracy:		89.24 %
# Epoch 68 of 200 took 2.528s
#   training loss:		0.089258
#   validation loss:		0.727273
#   validation accuracy:		89.19 %
# Epoch 69 of 200 took 2.528s
#   training loss:		0.088647
#   validation loss:		0.737887
#   validation accuracy:		89.13 %
# Epoch 70 of 200 took 2.528s
#   training loss:		0.088247
#   validation loss:		0.735052
#   validation accuracy:		89.16 %
# Epoch 71 of 200 took 2.528s
#   training loss:		0.088212
#   validation loss:		0.730451
#   validation accuracy:		89.19 %
# Epoch 72 of 200 took 2.528s
#   training loss:		0.088272
#   validation loss:		0.737916
#   validation accuracy:		89.03 %
# Epoch 73 of 200 took 2.528s
#   training loss:		0.088155
#   validation loss:		0.736760
#   validation accuracy:		89.08 %
# Epoch 74 of 200 took 2.528s
#   training loss:		0.087469
#   validation loss:		0.748734
#   validation accuracy:		89.13 %
# Epoch 75 of 200 took 2.528s
#   training loss:		0.087001
#   validation loss:		0.741553
#   validation accuracy:		89.08 %
# Epoch 76 of 200 took 2.528s
#   training loss:		0.087201
#   validation loss:		0.747765
#   validation accuracy:		89.05 %
# Epoch 77 of 200 took 2.528s
#   training loss:		0.086619
#   validation loss:		0.749479
#   validation accuracy:		89.10 %
# Epoch 78 of 200 took 2.528s
#   training loss:		0.086435
#   validation loss:		0.747957
#   validation accuracy:		89.10 %
# Epoch 79 of 200 took 2.528s
#   training loss:		0.086319
#   validation loss:		0.752153
#   validation accuracy:		89.05 %
# Epoch 80 of 200 took 2.528s
#   training loss:		0.086193
#   validation loss:		0.747227
#   validation accuracy:		89.11 %
# Epoch 81 of 200 took 2.528s
#   training loss:		0.086000
#   validation loss:		0.750912
#   validation accuracy:		89.02 %
# Epoch 82 of 200 took 2.529s
#   training loss:		0.085892
#   validation loss:		0.747976
#   validation accuracy:		89.16 %
# Epoch 83 of 200 took 2.528s
#   training loss:		0.085783
#   validation loss:		0.745007
#   validation accuracy:		89.21 %
# Epoch 84 of 200 took 2.528s
#   training loss:		0.085551
#   validation loss:		0.747057
#   validation accuracy:		89.24 %
# Epoch 85 of 200 took 2.528s
#   training loss:		0.085430
#   validation loss:		0.746921
#   validation accuracy:		89.24 %
# Epoch 86 of 200 took 2.528s
#   training loss:		0.085176
#   validation loss:		0.746704
#   validation accuracy:		89.21 %
# Epoch 87 of 200 took 2.529s
#   training loss:		0.084969
#   validation loss:		0.747149
#   validation accuracy:		89.18 %
# Epoch 88 of 200 took 2.529s
#   training loss:		0.084793
#   validation loss:		0.748079
#   validation accuracy:		89.19 %
# Epoch 89 of 200 took 2.528s
#   training loss:		0.084573
#   validation loss:		0.749760
#   validation accuracy:		89.21 %
# Epoch 90 of 200 took 2.528s
#   training loss:		0.084421
#   validation loss:		0.749141
#   validation accuracy:		89.11 %
# Epoch 91 of 200 took 2.528s
#   training loss:		0.084178
#   validation loss:		0.753438
#   validation accuracy:		89.10 %
# Epoch 92 of 200 took 2.529s
#   training loss:		0.083969
#   validation loss:		0.756414
#   validation accuracy:		89.03 %
# Epoch 93 of 200 took 2.528s
#   training loss:		0.083815
#   validation loss:		0.757368
#   validation accuracy:		89.08 %
# Epoch 94 of 200 took 2.528s
#   training loss:		0.083711
#   validation loss:		0.759298
#   validation accuracy:		89.02 %
# Epoch 95 of 200 took 2.529s
#   training loss:		0.083601
#   validation loss:		0.756487
#   validation accuracy:		89.06 %
# Epoch 96 of 200 took 2.529s
#   training loss:		0.083745
#   validation loss:		0.754388
#   validation accuracy:		89.05 %
# Epoch 97 of 200 took 2.528s
#   training loss:		0.083533
#   validation loss:		0.757596
#   validation accuracy:		89.06 %
# Epoch 98 of 200 took 2.528s
#   training loss:		0.083318
#   validation loss:		0.757667
#   validation accuracy:		89.11 %
# Epoch 99 of 200 took 2.529s
#   training loss:		0.083136
#   validation loss:		0.756815
#   validation accuracy:		89.10 %
# Epoch 100 of 200 took 2.529s
#   training loss:		0.082954
#   validation loss:		0.756630
#   validation accuracy:		89.11 %
# Epoch 101 of 200 took 2.528s
#   training loss:		0.082763
#   validation loss:		0.758428
#   validation accuracy:		89.08 %
# Epoch 102 of 200 took 2.529s
#   training loss:		0.082581
#   validation loss:		0.756193
#   validation accuracy:		89.08 %
# Epoch 103 of 200 took 2.528s
#   training loss:		0.082359
#   validation loss:		0.757889
#   validation accuracy:		89.11 %
# Epoch 104 of 200 took 2.528s
#   training loss:		0.082051
#   validation loss:		0.758194
#   validation accuracy:		89.13 %
# Epoch 105 of 200 took 2.529s
#   training loss:		0.081833
#   validation loss:		0.760190
#   validation accuracy:		89.11 %
# Epoch 106 of 200 took 2.529s
#   training loss:		0.081776
#   validation loss:		0.757934
#   validation accuracy:		89.11 %
# Epoch 107 of 200 took 2.529s
#   training loss:		0.081658
#   validation loss:		0.761309
#   validation accuracy:		89.11 %
# Epoch 108 of 200 took 2.529s
#   training loss:		0.081491
#   validation loss:		0.762218
#   validation accuracy:		89.16 %
# Epoch 109 of 200 took 2.528s
#   training loss:		0.081395
#   validation loss:		0.761007
#   validation accuracy:		89.15 %
# Epoch 110 of 200 took 2.528s
#   training loss:		0.081227
#   validation loss:		0.762686
#   validation accuracy:		89.15 %
# Epoch 111 of 200 took 2.529s
#   training loss:		0.081102
#   validation loss:		0.762138
#   validation accuracy:		89.16 %
# Epoch 112 of 200 took 2.529s
#   training loss:		0.080972
#   validation loss:		0.764641
#   validation accuracy:		89.15 %
# Epoch 113 of 200 took 2.529s
#   training loss:		0.080828
#   validation loss:		0.763543
#   validation accuracy:		89.16 %
# Epoch 114 of 200 took 2.529s
#   training loss:		0.080691
#   validation loss:		0.765338
#   validation accuracy:		89.18 %
# Epoch 115 of 200 took 2.529s
#   training loss:		0.080595
#   validation loss:		0.764457
#   validation accuracy:		89.13 %
# Epoch 116 of 200 took 2.529s
#   training loss:		0.080424
#   validation loss:		0.764914
#   validation accuracy:		89.13 %
# Epoch 117 of 200 took 2.529s
#   training loss:		0.080295
#   validation loss:		0.766764
#   validation accuracy:		89.13 %
# Epoch 118 of 200 took 2.529s
#   training loss:		0.080184
#   validation loss:		0.766645
#   validation accuracy:		89.16 %
# Epoch 119 of 200 took 2.528s
#   training loss:		0.080061
#   validation loss:		0.768381
#   validation accuracy:		89.18 %
# Epoch 120 of 200 took 2.529s
#   training loss:		0.079914
#   validation loss:		0.768403
#   validation accuracy:		89.16 %
# Epoch 121 of 200 took 2.529s
#   training loss:		0.079783
#   validation loss:		0.769459
#   validation accuracy:		89.15 %
# Epoch 122 of 200 took 2.529s
#   training loss:		0.079683
#   validation loss:		0.768634
#   validation accuracy:		89.15 %
# Epoch 123 of 200 took 2.529s
#   training loss:		0.079541
#   validation loss:		0.771312
#   validation accuracy:		89.10 %
# Epoch 124 of 200 took 2.529s
#   training loss:		0.079398
#   validation loss:		0.769678
#   validation accuracy:		89.15 %
# Epoch 125 of 200 took 2.529s
#   training loss:		0.079276
#   validation loss:		0.771705
#   validation accuracy:		89.11 %
# Epoch 126 of 200 took 2.529s
#   training loss:		0.079208
#   validation loss:		0.768786
#   validation accuracy:		89.16 %
# Epoch 127 of 200 took 2.529s
#   training loss:		0.079037
#   validation loss:		0.772661
#   validation accuracy:		89.10 %
# Epoch 128 of 200 took 2.529s
#   training loss:		0.078929
#   validation loss:		0.770210
#   validation accuracy:		89.10 %
# Epoch 129 of 200 took 2.529s
#   training loss:		0.078796
#   validation loss:		0.770250
#   validation accuracy:		89.10 %
# Epoch 130 of 200 took 2.529s
#   training loss:		0.078684
#   validation loss:		0.771698
#   validation accuracy:		89.15 %
# Epoch 131 of 200 took 2.529s
#   training loss:		0.078583
#   validation loss:		0.771876
#   validation accuracy:		89.03 %
# Epoch 132 of 200 took 2.528s
#   training loss:		0.078445
#   validation loss:		0.771658
#   validation accuracy:		89.11 %
# Epoch 133 of 200 took 2.529s
#   training loss:		0.078307
#   validation loss:		0.772465
#   validation accuracy:		89.18 %
# Epoch 134 of 200 took 2.529s
#   training loss:		0.078228
#   validation loss:		0.774281
#   validation accuracy:		89.13 %
# Epoch 135 of 200 took 2.529s
#   training loss:		0.078113
#   validation loss:		0.773295
#   validation accuracy:		89.19 %
# Epoch 136 of 200 took 2.529s
#   training loss:		0.077991
#   validation loss:		0.774078
#   validation accuracy:		89.13 %
# Epoch 137 of 200 took 2.529s
#   training loss:		0.077886
#   validation loss:		0.773442
#   validation accuracy:		89.15 %
# Epoch 138 of 200 took 2.529s
#   training loss:		0.077775
#   validation loss:		0.773434
#   validation accuracy:		89.11 %
# Epoch 139 of 200 took 2.529s
#   training loss:		0.077686
#   validation loss:		0.776432
#   validation accuracy:		89.16 %
# Epoch 140 of 200 took 2.528s
#   training loss:		0.077558
#   validation loss:		0.775421
#   validation accuracy:		89.11 %
# Epoch 141 of 200 took 2.529s
#   training loss:		0.077460
#   validation loss:		0.775783
#   validation accuracy:		89.06 %
# Epoch 142 of 200 took 2.529s
#   training loss:		0.077324
#   validation loss:		0.778312
#   validation accuracy:		89.16 %
# Epoch 143 of 200 took 2.528s
#   training loss:		0.077261
#   validation loss:		0.775984
#   validation accuracy:		89.08 %
# Epoch 144 of 200 took 2.530s
#   training loss:		0.077148
#   validation loss:		0.777334
#   validation accuracy:		89.15 %
# Epoch 145 of 200 took 2.530s
#   training loss:		0.077052
#   validation loss:		0.777887
#   validation accuracy:		89.02 %
# Epoch 146 of 200 took 2.529s
#   training loss:		0.076961
#   validation loss:		0.777183
#   validation accuracy:		89.06 %
# Epoch 147 of 200 took 2.530s
#   training loss:		0.076854
#   validation loss:		0.776825
#   validation accuracy:		89.11 %
# Epoch 148 of 200 took 2.530s
#   training loss:		0.076744
#   validation loss:		0.777491
#   validation accuracy:		89.11 %
# Epoch 149 of 200 took 2.530s
#   training loss:		0.076649
#   validation loss:		0.778857
#   validation accuracy:		89.11 %
# Epoch 150 of 200 took 2.529s
#   training loss:		0.076558
#   validation loss:		0.781159
#   validation accuracy:		89.10 %
# Epoch 151 of 200 took 2.530s
#   training loss:		0.076470
#   validation loss:		0.779707
#   validation accuracy:		89.03 %
# Epoch 152 of 200 took 2.529s
#   training loss:		0.076367
#   validation loss:		0.780306
#   validation accuracy:		89.03 %
# Epoch 153 of 200 took 2.531s
#   training loss:		0.076286
#   validation loss:		0.779629
#   validation accuracy:		89.06 %
# Epoch 154 of 200 took 2.530s
#   training loss:		0.076187
#   validation loss:		0.780651
#   validation accuracy:		89.13 %
# Epoch 155 of 200 took 2.529s
#   training loss:		0.076109
#   validation loss:		0.780447
#   validation accuracy:		89.03 %
# Epoch 156 of 200 took 2.530s
#   training loss:		0.076023
#   validation loss:		0.782534
#   validation accuracy:		89.10 %
# Epoch 157 of 200 took 2.529s
#   training loss:		0.075922
#   validation loss:		0.782318
#   validation accuracy:		89.06 %
# Epoch 158 of 200 took 2.529s
#   training loss:		0.075844
#   validation loss:		0.782132
#   validation accuracy:		89.06 %
# Epoch 159 of 200 took 2.530s
#   training loss:		0.075731
#   validation loss:		0.783117
#   validation accuracy:		89.06 %
# Epoch 160 of 200 took 2.529s
#   training loss:		0.075663
#   validation loss:		0.782506
#   validation accuracy:		89.13 %
# Epoch 161 of 200 took 2.529s
#   training loss:		0.075561
#   validation loss:		0.783243
#   validation accuracy:		89.03 %
# Epoch 162 of 200 took 2.530s
#   training loss:		0.075487
#   validation loss:		0.784090
#   validation accuracy:		89.05 %
# Epoch 163 of 200 took 2.530s
#   training loss:		0.075403
#   validation loss:		0.784335
#   validation accuracy:		89.05 %
# Epoch 164 of 200 took 2.530s
#   training loss:		0.075328
#   validation loss:		0.782440
#   validation accuracy:		89.06 %
# Epoch 165 of 200 took 2.530s
#   training loss:		0.075237
#   validation loss:		0.784204
#   validation accuracy:		89.03 %
# Epoch 166 of 200 took 2.529s
#   training loss:		0.075149
#   validation loss:		0.784039
#   validation accuracy:		89.02 %
# Epoch 167 of 200 took 2.529s
#   training loss:		0.075055
#   validation loss:		0.786679
#   validation accuracy:		89.02 %
# Epoch 168 of 200 took 2.530s
#   training loss:		0.074980
#   validation loss:		0.782870
#   validation accuracy:		89.02 %
# Epoch 169 of 200 took 2.529s
#   training loss:		0.074904
#   validation loss:		0.783816
#   validation accuracy:		89.02 %
# Epoch 170 of 200 took 2.530s
#   training loss:		0.074830
#   validation loss:		0.784670
#   validation accuracy:		89.08 %
# Epoch 171 of 200 took 2.530s
#   training loss:		0.074747
#   validation loss:		0.788002
#   validation accuracy:		88.94 %
# Epoch 172 of 200 took 2.530s
#   training loss:		0.074697
#   validation loss:		0.784495
#   validation accuracy:		89.00 %
# Epoch 173 of 200 took 2.530s
#   training loss:		0.074583
#   validation loss:		0.787223
#   validation accuracy:		89.08 %
# Epoch 174 of 200 took 2.530s
#   training loss:		0.074524
#   validation loss:		0.786884
#   validation accuracy:		89.00 %
# Epoch 175 of 200 took 2.530s
#   training loss:		0.074442
#   validation loss:		0.788102
#   validation accuracy:		89.02 %
# Epoch 176 of 200 took 2.529s
#   training loss:		0.074358
#   validation loss:		0.787196
#   validation accuracy:		89.03 %
# Epoch 177 of 200 took 2.530s
#   training loss:		0.074290
#   validation loss:		0.787638
#   validation accuracy:		88.97 %
# Epoch 178 of 200 took 2.530s
#   training loss:		0.074217
#   validation loss:		0.786552
#   validation accuracy:		88.98 %
# Epoch 179 of 200 took 2.530s
#   training loss:		0.074132
#   validation loss:		0.786223
#   validation accuracy:		89.00 %
# Epoch 180 of 200 took 2.530s
#   training loss:		0.074053
#   validation loss:		0.788692
#   validation accuracy:		89.00 %
# Epoch 181 of 200 took 2.530s
#   training loss:		0.073964
#   validation loss:		0.787135
#   validation accuracy:		89.05 %
# Epoch 182 of 200 took 2.530s
#   training loss:		0.073900
#   validation loss:		0.788364
#   validation accuracy:		89.02 %
# Epoch 183 of 200 took 2.530s
#   training loss:		0.073836
#   validation loss:		0.790378
#   validation accuracy:		89.06 %
# Epoch 184 of 200 took 2.530s
#   training loss:		0.073781
#   validation loss:		0.789750
#   validation accuracy:		88.98 %
# Epoch 185 of 200 took 2.530s
#   training loss:		0.073693
#   validation loss:		0.789414
#   validation accuracy:		89.05 %
# Epoch 186 of 200 took 2.530s
#   training loss:		0.073628
#   validation loss:		0.791498
#   validation accuracy:		89.05 %
# Epoch 187 of 200 took 2.530s
#   training loss:		0.073559
#   validation loss:		0.790482
#   validation accuracy:		89.06 %
# Epoch 188 of 200 took 2.530s
#   training loss:		0.073476
#   validation loss:		0.790956
#   validation accuracy:		89.03 %
# Epoch 189 of 200 took 2.530s
#   training loss:		0.073416
#   validation loss:		0.791547
#   validation accuracy:		89.08 %
# Epoch 190 of 200 took 2.530s
#   training loss:		0.073344
#   validation loss:		0.794601
#   validation accuracy:		89.02 %
# Epoch 191 of 200 took 2.530s
#   training loss:		0.073306
#   validation loss:		0.791645
#   validation accuracy:		89.02 %
# Epoch 192 of 200 took 2.529s
#   training loss:		0.073232
#   validation loss:		0.791941
#   validation accuracy:		89.05 %
# Epoch 193 of 200 took 2.532s
#   training loss:		0.073168
#   validation loss:		0.792512
#   validation accuracy:		89.06 %
# Epoch 194 of 200 took 2.522s
#   training loss:		0.073092
#   validation loss:		0.793177
#   validation accuracy:		89.08 %
# Epoch 195 of 200 took 2.523s
#   training loss:		0.073023
#   validation loss:		0.791308
#   validation accuracy:		89.05 %
# Epoch 196 of 200 took 2.523s
#   training loss:		0.072976
#   validation loss:		0.795801
#   validation accuracy:		89.03 %
# Epoch 197 of 200 took 2.525s
#   training loss:		0.072909
#   validation loss:		0.793485
#   validation accuracy:		89.08 %
# Epoch 198 of 200 took 2.514s
#   training loss:		0.072847
#   validation loss:		0.793802
#   validation accuracy:		89.06 %
# Epoch 199 of 200 took 2.513s
#   training loss:		0.072761
#   validation loss:		0.795909
#   validation accuracy:		89.08 %
# Epoch 200 of 200 took 2.513s
#   training loss:		0.072728
#   validation loss:		0.794720
#   validation accuracy:		89.05 %

# %% [markdown]
# Now let's create a function that computes the latent representation variables z so we can visualize them on the test set.

# %%
z = nn.layers.get_output(l_latent)

compute_z = theano.function(
    [], z,
    givens={
        x: dataset['X_test'],
    },
)

z_vals = compute_z()

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(z_vals[:, 0], z_vals[:, 1], alpha=0.1)
plt.show()

# %% [markdown]
# This corresponds to figure 4a in the paper. Our latent variables have a smaller magnitude overall, but exhibit a roughly Gaussian distribution just like in the paper.
#
# Now let's generate some reconstructions. Our aim is to reproduce figures 4b and 4c. We'll need to compile a function that allows us to set the desired values for the latent variables `y` and `z`.
#
# Lasagne makes it possible to map any layer in the network to a custom expression by supplying a dictionary to `nn.layers.get_output()`. We'll make use of this to 'clamp' the observed and latent representation variables.

# %%
y_clamped = T.ivector('y_clamped')
z_clamped = T.matrix('z_clamped')

x_recon = nn.layers.get_output(l_decoder_out, {
        l_observed: nn.utils.one_hot(y_clamped, m=dataset["output_dim"]),
        l_latent: z_clamped,
    })

reconstruct = theano.function([y_clamped, z_clamped], x_recon)

# %%
R = 30
ys = np.repeat(np.arange(dataset["output_dim"]), R).astype('int32')
zs = np.tile(np.linspace(-0.5, 0.5, R), dataset["output_dim"]).astype(theano.config.floatX)
z1s = np.vstack([zs, np.zeros_like(zs)]).T
z2s = np.vstack([np.zeros_like(zs), zs]).T

# %%
reconstructions_z1 = reconstruct(ys, z1s)
reconstructions_z2 = reconstruct(ys, z2s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-5b1297da8c5c> in <module>()
# ----> 1 reconstructions_z1 = reconstruct(ys, z1s)
#       2 reconstructions_z2 = reconstruct(ys, z2s)
#
# /grid_mnt/vol__vol_U__u/gridcl/mehdicherti/build/Theano/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     604                         self.fn.nodes[self.fn.position_of_error],
#     605                         self.fn.thunks[self.fn.position_of_error],
# --> 606                         storage_map=self.fn.storage_map)
#     607                 else:
#     608                     # For the c linker We don't have access from
#
# /grid_mnt/vol__vol_U__u/gridcl/mehdicherti/build/Theano/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# ValueError: dimension mismatch in args to gemm (780,28)x(56,500)->(780,500)
# Apply node that caused the error: GpuDot22(GpuFromHost.0, W)
# Inputs types: [CudaNdarrayType(float32, matrix), CudaNdarrayType(float32, matrix)]
# Inputs shapes: [(780, 28), (56, 500)]
# Inputs strides: [(28, 1), (500, 1)]
# Inputs values: ['not shown', 'not shown']
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.

# %%
im1 = reconstructions_z1.reshape(dataset["output_dim"], R, w, h).transpose(1, 2, 0, 3).reshape(R * w, dataset["output_dim"] * h)
plt.imshow(im1, cmap=plt.cm.gray)
plt.show()

# %%
im2 = reconstructions_z2.reshape(dataset["output_dim"], 9, w, h).transpose(1, 2, 0, 3).reshape(9 * w, dataset["output_dim"] * h)
plt.imshow(im2, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# The reconstructions show some interesting structure as `z1` and `z2` are varied. Pretty cool!

# %%
reconstructions_z1.shape
for i in range(reconstructions_z1.shape[0]):
    plt.clf()
    plt.imshow(reconstructions_z1[i].reshape((64, 64)), cmap="gray")
    plt.show()
