# %% [markdown]
# # Discovering hidden factors of variation in deep networks
#
# **This is an example of how to implement the autoencoder architecture from [Cheung et al. (2014)](http://arxiv.org/abs/1412.6583) in Lasagne.** This uses the code from the MNIST example bundled with Lasagne, so you will need to have the `mnist.py` file available for importing.

# %%
# %matplotlib inline

# %%
import numpy as np
import theano
import theano.tensor as T
import lasagne as nn
w, h = 64, 64

# %%
from skimage.transform import resize
from skimage.filter import threshold_otsu

def binarize(X):
    X_b = np.empty(X.shape, dtype=X.dtype)
    for i in range(X.shape[0]):
        X_b[i] = 1. * (X[i] <= threshold_otsu(X[i]))
    return X_b

def resize_all(X, w, h):
    if X.shape[1] == w and X.shape[2] == h:
        return X
    X_b = np.empty((X.shape[0], w, h), dtype=X.dtype)
    for i in range(X.shape[0]):
        X_b[i] = resize(X[i], (w, h))
    return X_b

# %% [markdown]
# **We'll define the model listed in the first column of Table 1 in the paper.**
#
# This model has an encoder with two ReLU layers. In the paper they both have 500 units but we'll make this configurable so we can speed up the experiment a bit if necessary.
#
# On top of the encoder are two representation layers: one is a 10-way softmax layer which represents the class of the input. This is the observed representation layer. Then there is also a latent representation layer which has two additional linear units (the authors use only two units for easy visualization).
#
# Both representation layers are concatenated and the decoder is stacked on top. This consists of three layers: two hidden ReLU layers with again 500 units, and finally a linear reconstruction layer with 784 outputs.

# %%
def build_model(input_dim, output_dim, batch_size,
                num_hidden_units=500):
    l_in = nn.layers.InputLayer((batch_size, input_dim))
    
    # encoder
    l_encoder1 = nn.layers.DenseLayer(l_in, num_units=num_hidden_units)
    l_encoder2 = nn.layers.DenseLayer(l_encoder1, num_units=num_hidden_units)
    
    # learned representation
    l_observed = nn.layers.DenseLayer(l_encoder2, num_units=output_dim,
                                      nonlinearity=T.nnet.softmax)
    
    l_latent = nn.layers.DenseLayer(l_encoder2, num_units=2,
                                    nonlinearity=None) # linear
    
    l_representation = nn.layers.concat([l_observed, l_latent])
    
    # decoder
    l_decoder1 = nn.layers.DenseLayer(l_representation, num_units=num_hidden_units)
    l_decoder2 = nn.layers.DenseLayer(l_decoder1, num_units=num_hidden_units)
    l_decoder_out = nn.layers.DenseLayer(l_decoder2, num_units=input_dim,
                                       nonlinearity=None)
    
    return l_in, l_decoder_out, l_observed, l_latent

# %% [markdown]
# Next, **we'll define the cost function**. This consists of three parts: `alpha * U + beta * S + gamma * C` (formula 3 in the paper). `U` is the reconstruction cost, `S` is the supervised cost and `C` is the so-called "XCov" cost which disentangles the observed and latent variables of the encoder.

# %%
def cost(x, y, x_recon, y_pred, z, alpha=1.0, beta=10.0, gamma=10.0):
    """
    x, y: the input and the corresponding label
    x_recon: the model reconstruction of the input
    y_pred: the model prediction (observed variables)
    z: the latent variables
    """
    # reconstruction cost: mean squared error
    U = T.mean((x - x_recon)**2)
    
    # supervised cost: categorical cross-entropy
    S = T.mean(T.nnet.categorical_crossentropy(y_pred, y))
    
    # XCov cost: cross-covariance
    y_pred_mean = T.mean(y_pred, axis=0, keepdims=True)
    z_mean = T.mean(z, axis=0, keepdims=True)
    y_pred_centered = y_pred - y_pred_mean # (n, i)
    z_centered = z - z_mean # (n, j)
    
    outer_prod = (y_pred_centered.dimshuffle(0, 1, 'x') *
                  z_centered.dimshuffle(0, 'x', 1)) # (n, i, j)
    C = 0.5 * T.sum(T.sqr(T.mean(outer_prod, axis=0)))
    
    # the total cost is a weighted sum
    return alpha * U + beta * S + gamma * C

# %%
from lasagne.datasets.mnist import MNIST
from sklearn.cross_validation import train_test_split
import lasagne.easy

def load_data():
    """Get data with labels, split into training, validation and test set."""
    from lasagne.datasets.fonts import Fonts
    
    #data = Fonts(kind="all_64")
    #data.load()
    
    data = MNIST()
    data.load()
    
    X = data.X
    X = X.reshape((X.shape[0], 28, 28))
    X = resize_all(X, w, h)
    X = binarize(X)
    X = 1 - X
    X = X.astype(np.float32)
    X = X.reshape((X.shape[0], w*h))
    y = data.y
    
    X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.25)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.25)
    
    return dict(
        X_train=theano.shared(lasagne.utils.floatX(X_train)),
        y_train=T.cast(theano.shared(y_train), 'int32'),
        X_valid=theano.shared(lasagne.utils.floatX(X_valid)),
        y_valid=T.cast(theano.shared(y_valid), 'int32'),
        X_test=theano.shared(lasagne.utils.floatX(X_test)),
        y_test=T.cast(theano.shared(y_test), 'int32'),
        num_examples_train=X_train.shape[0],
        num_examples_valid=X_valid.shape[0],
        num_examples_test=X_test.shape[0],
        input_dim=X_train.shape[1],
        output_dim=10,
    )

# %% [markdown]
# Now let's tie everything together in the main training loop.

# %%
from mnist import train
import time

num_epochs = 200
batch_size = 100

print("Loading data...")
dataset = load_data()
print(dataset.keys())
# Out:
# Loading data...
# ['X_test', 'num_examples_train', 'X_train', 'num_examples_valid', 'num_examples_test', 'output_dim', 'X_valid', 'y_valid', 'y_train', 'input_dim', 'y_test']

# %%
print("Building model and compiling functions...")
l_in, l_decoder_out, l_observed, l_latent = build_model(
    input_dim=dataset['input_dim'],
    output_dim=dataset['output_dim'],
    batch_size=batch_size,
)

x = l_in.input_var
y = T.ivector('y')
x_recon, y_pred, z = nn.layers.get_output([l_decoder_out, l_observed, l_latent])
# Note that we call get_output() once to get all the model outputs.
# This is to guarantee they are consistent and share computations where
# possible. When the network contains nondeterminism (such as dropout
# regularization), guaranteeing this consistency is crucially important.
loss = cost(x, y, x_recon, y_pred, z)
params = nn.layers.get_all_params(l_decoder_out)

# # add some L2 regularization
# params_reg = nn.layers.get_all_params(l_decoder_out, regularizable=True)
# reg = sum(T.sum(p**2) for p in params_reg)
# loss += 0.01 * reg

# The authors mention that they use adadelta, let's do the same
updates = nn.updates.adadelta(loss, params)

# compile iteration functions
batch_index = T.iscalar('batch_index')
batch_slice = slice(batch_index * batch_size,
                    (batch_index + 1) * batch_size)

pred = T.argmax(y_pred, axis=1)
accuracy = T.mean(T.eq(pred, y), dtype=theano.config.floatX)

iter_train = theano.function(
    [batch_index], loss,
    updates=updates,
    givens={
        x: dataset['X_train'][batch_slice],
        y: dataset['y_train'][batch_slice],
    },
)

iter_valid = theano.function(
    [batch_index], [loss, accuracy],
    givens={
        x: dataset['X_valid'][batch_slice],
        y: dataset['y_valid'][batch_slice],
    },
)

iter_test = theano.function(
    [batch_index], [loss, accuracy],
    givens={
        x: dataset['X_test'][batch_slice],
        y: dataset['y_test'][batch_slice],
    },
)

iter_funcs =  dict(
    train=iter_train,
    valid=iter_valid,
    test=iter_test,
)

print("Starting training...")
now = time.time()
try:
    for epoch in train(iter_funcs, dataset, batch_size=batch_size):
        print("Epoch {} of {} took {:.3f}s".format(
            epoch['number'], num_epochs, time.time() - now))
        now = time.time()
        print("  training loss:\t\t{:.6f}".format(epoch['train_loss']))
        print("  validation loss:\t\t{:.6f}".format(epoch['valid_loss']))
        print("  validation accuracy:\t\t{:.2f} %".format(
            epoch['valid_accuracy'] * 100))

        if epoch['number'] >= num_epochs:
            break

except KeyboardInterrupt:
    pass
# Out:
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 200 took 4.224s
#   training loss:		3.865853
#   validation loss:		1.729030
#   validation accuracy:		95.27 %
# Epoch 2 of 200 took 4.216s
#   training loss:		1.214645
#   validation loss:		1.873403
#   validation accuracy:		95.11 %
# Epoch 3 of 200 took 4.217s
#   training loss:		0.729728
#   validation loss:		1.670392
#   validation accuracy:		96.23 %
# Epoch 4 of 200 took 4.217s
#   training loss:		0.468180
#   validation loss:		1.522876
#   validation accuracy:		96.76 %
# Epoch 5 of 200 took 4.215s
#   training loss:		0.351329
#   validation loss:		1.820900
#   validation accuracy:		96.74 %
# Epoch 6 of 200 took 4.216s
#   training loss:		0.287746
#   validation loss:		1.633214
#   validation accuracy:		96.98 %
# Epoch 7 of 200 took 4.218s
#   training loss:		0.219759
#   validation loss:		1.576341
#   validation accuracy:		97.14 %
# Epoch 8 of 200 took 4.217s
#   training loss:		0.187649
#   validation loss:		1.452269
#   validation accuracy:		97.46 %
# Epoch 9 of 200 took 4.216s
#   training loss:		0.152516
#   validation loss:		1.540553
#   validation accuracy:		97.37 %
# Epoch 10 of 200 took 4.216s
#   training loss:		0.127726
#   validation loss:		1.288458
#   validation accuracy:		97.85 %
# Epoch 11 of 200 took 4.216s
#   training loss:		0.117564
#   validation loss:		1.480287
#   validation accuracy:		97.50 %
# Epoch 12 of 200 took 4.215s
#   training loss:		0.105185
#   validation loss:		1.406968
#   validation accuracy:		97.64 %
# Epoch 13 of 200 took 4.217s
#   training loss:		0.096020
#   validation loss:		1.257826
#   validation accuracy:		97.76 %
# Epoch 14 of 200 took 4.216s
#   training loss:		0.082557
#   validation loss:		1.083651
#   validation accuracy:		98.00 %
# Epoch 15 of 200 took 4.224s
#   training loss:		0.079123
#   validation loss:		1.048482
#   validation accuracy:		98.12 %
# Epoch 16 of 200 took 4.220s
#   training loss:		0.077839
#   validation loss:		1.042958
#   validation accuracy:		98.13 %
# Epoch 17 of 200 took 4.219s
#   training loss:		0.077340
#   validation loss:		1.024539
#   validation accuracy:		98.15 %
# Epoch 18 of 200 took 4.219s
#   training loss:		0.076637
#   validation loss:		1.021933
#   validation accuracy:		98.08 %
# Epoch 19 of 200 took 4.220s
#   training loss:		0.076363
#   validation loss:		1.028980
#   validation accuracy:		98.11 %
# Epoch 20 of 200 took 4.220s
#   training loss:		0.075890
#   validation loss:		1.030330
#   validation accuracy:		98.13 %
# Epoch 21 of 200 took 4.223s
#   training loss:		0.075686
#   validation loss:		1.032700
#   validation accuracy:		98.12 %
# Epoch 22 of 200 took 4.221s
#   training loss:		0.075361
#   validation loss:		1.038357
#   validation accuracy:		98.10 %
# Epoch 23 of 200 took 4.269s
#   training loss:		0.075346
#   validation loss:		1.032995
#   validation accuracy:		98.08 %
# Epoch 24 of 200 took 4.227s
#   training loss:		0.074979
#   validation loss:		1.043293
#   validation accuracy:		98.09 %
# Epoch 25 of 200 took 4.220s
#   training loss:		0.074835
#   validation loss:		1.042472
#   validation accuracy:		98.10 %
# Epoch 26 of 200 took 4.220s
#   training loss:		0.074512
#   validation loss:		1.041235
#   validation accuracy:		98.10 %
# Epoch 27 of 200 took 4.219s
#   training loss:		0.074236
#   validation loss:		1.042758
#   validation accuracy:		98.11 %
# Epoch 28 of 200 took 4.220s
#   training loss:		0.073953
#   validation loss:		1.041773
#   validation accuracy:		98.11 %
# Epoch 29 of 200 took 4.221s
#   training loss:		0.073743
#   validation loss:		1.043756
#   validation accuracy:		98.08 %
# Epoch 30 of 200 took 4.220s
#   training loss:		0.073432
#   validation loss:		1.047477
#   validation accuracy:		98.07 %
# Epoch 31 of 200 took 4.220s
#   training loss:		0.073162
#   validation loss:		1.049332
#   validation accuracy:		98.05 %
# Epoch 32 of 200 took 4.220s
#   training loss:		0.072958
#   validation loss:		1.051441
#   validation accuracy:		98.03 %
# Epoch 33 of 200 took 4.221s
#   training loss:		0.072763
#   validation loss:		1.054359
#   validation accuracy:		98.03 %
# Epoch 34 of 200 took 4.220s
#   training loss:		0.072556
#   validation loss:		1.056126
#   validation accuracy:		98.02 %
# Epoch 35 of 200 took 4.221s
#   training loss:		0.072391
#   validation loss:		1.057634
#   validation accuracy:		98.02 %
# Epoch 36 of 200 took 4.220s
#   training loss:		0.072191
#   validation loss:		1.058601
#   validation accuracy:		98.02 %
# Epoch 37 of 200 took 4.220s
#   training loss:		0.072031
#   validation loss:		1.060552
#   validation accuracy:		98.01 %
# Epoch 38 of 200 took 4.220s
#   training loss:		0.071820
#   validation loss:		1.060423
#   validation accuracy:		98.00 %
# Epoch 39 of 200 took 4.219s
#   training loss:		0.071648
#   validation loss:		1.062104
#   validation accuracy:		97.99 %
# Epoch 40 of 200 took 4.220s
#   training loss:		0.071448
#   validation loss:		1.063497
#   validation accuracy:		98.02 %
# Epoch 41 of 200 took 4.219s
#   training loss:		0.071249
#   validation loss:		1.064343
#   validation accuracy:		98.02 %
# Epoch 42 of 200 took 4.220s
#   training loss:		0.071063
#   validation loss:		1.067128
#   validation accuracy:		98.02 %
# Epoch 43 of 200 took 4.221s
#   training loss:		0.070856
#   validation loss:		1.069886
#   validation accuracy:		98.04 %
# Epoch 44 of 200 took 4.292s
#   training loss:		0.070671
#   validation loss:		1.072720
#   validation accuracy:		98.04 %
# Epoch 45 of 200 took 4.208s
#   training loss:		0.070485
#   validation loss:		1.074880
#   validation accuracy:		98.03 %
# Epoch 46 of 200 took 4.208s
#   training loss:		0.070290
#   validation loss:		1.078140
#   validation accuracy:		98.03 %
# Epoch 47 of 200 took 4.207s
#   training loss:		0.070119
#   validation loss:		1.080356
#   validation accuracy:		98.04 %
# Epoch 48 of 200 took 4.208s
#   training loss:		0.070012
#   validation loss:		1.081541
#   validation accuracy:		98.04 %
# Epoch 49 of 200 took 4.208s
#   training loss:		0.069836
#   validation loss:		1.082664
#   validation accuracy:		98.05 %
# Epoch 50 of 200 took 4.209s
#   training loss:		0.069705
#   validation loss:		1.082936
#   validation accuracy:		98.05 %
# Epoch 51 of 200 took 4.204s
#   training loss:		0.069478
#   validation loss:		1.088010
#   validation accuracy:		98.01 %
# Epoch 52 of 200 took 4.199s
#   training loss:		0.069325
#   validation loss:		1.089425
#   validation accuracy:		98.02 %
# Epoch 53 of 200 took 4.200s
#   training loss:		0.069165
#   validation loss:		1.091668
#   validation accuracy:		98.04 %
# Epoch 54 of 200 took 4.199s
#   training loss:		0.068970
#   validation loss:		1.092842
#   validation accuracy:		98.02 %
# Epoch 55 of 200 took 4.209s
#   training loss:		0.068889
#   validation loss:		1.088656
#   validation accuracy:		98.07 %
# Epoch 56 of 200 took 4.223s
#   training loss:		0.068670
#   validation loss:		1.095358
#   validation accuracy:		98.04 %
# Epoch 57 of 200 took 4.224s
#   training loss:		0.068396
#   validation loss:		1.098303
#   validation accuracy:		98.02 %
# Epoch 58 of 200 took 4.224s
#   training loss:		0.068266
#   validation loss:		1.095600
#   validation accuracy:		98.02 %
# Epoch 59 of 200 took 4.224s
#   training loss:		0.068065
#   validation loss:		1.098717
#   validation accuracy:		98.05 %
# Epoch 60 of 200 took 4.223s
#   training loss:		0.067852
#   validation loss:		1.101341
#   validation accuracy:		98.05 %
# Epoch 61 of 200 took 4.224s
#   training loss:		0.067616
#   validation loss:		1.103841
#   validation accuracy:		98.06 %
# Epoch 62 of 200 took 4.236s
#   training loss:		0.067392
#   validation loss:		1.104515
#   validation accuracy:		98.06 %
# Epoch 63 of 200 took 4.283s
#   training loss:		0.067201
#   validation loss:		1.103048
#   validation accuracy:		98.06 %
# Epoch 64 of 200 took 4.280s
#   training loss:		0.066979
#   validation loss:		1.105920
#   validation accuracy:		98.04 %
# Epoch 65 of 200 took 4.206s
#   training loss:		0.066734
#   validation loss:		1.105592
#   validation accuracy:		98.06 %
# Epoch 66 of 200 took 4.211s
#   training loss:		0.066532
#   validation loss:		1.106460
#   validation accuracy:		98.03 %
# Epoch 67 of 200 took 4.223s
#   training loss:		0.066300
#   validation loss:		1.108473
#   validation accuracy:		98.05 %
# Epoch 68 of 200 took 4.223s
#   training loss:		0.066068
#   validation loss:		1.110684
#   validation accuracy:		98.03 %
# Epoch 69 of 200 took 4.224s
#   training loss:		0.065860
#   validation loss:		1.111496
#   validation accuracy:		98.02 %
# Epoch 70 of 200 took 4.224s
#   training loss:		0.065660
#   validation loss:		1.111789
#   validation accuracy:		98.03 %
# Epoch 71 of 200 took 4.224s
#   training loss:		0.065453
#   validation loss:		1.113286
#   validation accuracy:		98.05 %
# Epoch 72 of 200 took 4.223s
#   training loss:		0.065249
#   validation loss:		1.113977
#   validation accuracy:		98.05 %
# Epoch 73 of 200 took 4.224s
#   training loss:		0.065053
#   validation loss:		1.115781
#   validation accuracy:		98.05 %
# Epoch 74 of 200 took 4.225s
#   training loss:		0.064852
#   validation loss:		1.117145
#   validation accuracy:		98.05 %
# Epoch 75 of 200 took 4.224s
#   training loss:		0.064706
#   validation loss:		1.117509
#   validation accuracy:		98.05 %
# Epoch 76 of 200 took 4.224s
#   training loss:		0.064538
#   validation loss:		1.120471
#   validation accuracy:		98.04 %
# Epoch 77 of 200 took 4.225s
#   training loss:		0.064324
#   validation loss:		1.118480
#   validation accuracy:		98.05 %
# Epoch 78 of 200 took 4.224s
#   training loss:		0.064141
#   validation loss:		1.120619
#   validation accuracy:		98.05 %
# Epoch 79 of 200 took 4.230s
#   training loss:		0.063937
#   validation loss:		1.121104
#   validation accuracy:		98.04 %
# Epoch 80 of 200 took 4.223s
#   training loss:		0.063826
#   validation loss:		1.120380
#   validation accuracy:		98.04 %
# Epoch 81 of 200 took 4.223s
#   training loss:		0.063658
#   validation loss:		1.121037
#   validation accuracy:		98.05 %
# Epoch 82 of 200 took 4.227s
#   training loss:		0.063491
#   validation loss:		1.118864
#   validation accuracy:		98.05 %
# Epoch 83 of 200 took 4.221s
#   training loss:		0.063330
#   validation loss:		1.122099
#   validation accuracy:		98.05 %
# Epoch 84 of 200 took 4.206s
#   training loss:		0.063173
#   validation loss:		1.118306
#   validation accuracy:		98.07 %
# Epoch 85 of 200 took 4.209s
#   training loss:		0.063013
#   validation loss:		1.123572
#   validation accuracy:		98.06 %
# Epoch 86 of 200 took 4.206s
#   training loss:		0.062849
#   validation loss:		1.121849
#   validation accuracy:		98.06 %
# Epoch 87 of 200 took 4.207s
#   training loss:		0.062739
#   validation loss:		1.122391
#   validation accuracy:		98.05 %
# Epoch 88 of 200 took 4.209s
#   training loss:		0.062569
#   validation loss:		1.122663
#   validation accuracy:		98.04 %
# Epoch 89 of 200 took 4.206s
#   training loss:		0.062415
#   validation loss:		1.123298
#   validation accuracy:		98.05 %
# Epoch 90 of 200 took 4.208s
#   training loss:		0.062285
#   validation loss:		1.119935
#   validation accuracy:		98.05 %
# Epoch 91 of 200 took 4.200s
#   training loss:		0.062110
#   validation loss:		1.125901
#   validation accuracy:		98.02 %
# Epoch 92 of 200 took 4.198s
#   training loss:		0.062043
#   validation loss:		1.122735
#   validation accuracy:		98.05 %
# Epoch 93 of 200 took 4.199s
#   training loss:		0.061854
#   validation loss:		1.121891
#   validation accuracy:		98.05 %
# Epoch 94 of 200 took 4.199s
#   training loss:		0.061727
#   validation loss:		1.121702
#   validation accuracy:		98.05 %
# Epoch 95 of 200 took 4.211s
#   training loss:		0.061598
#   validation loss:		1.124450
#   validation accuracy:		98.04 %
# Epoch 96 of 200 took 4.223s
#   training loss:		0.061408
#   validation loss:		1.127876
#   validation accuracy:		98.02 %
# Epoch 97 of 200 took 4.355s
#   training loss:		0.061278
#   validation loss:		1.128354
#   validation accuracy:		98.01 %
# Epoch 98 of 200 took 4.208s
#   training loss:		0.061226
#   validation loss:		1.120469
#   validation accuracy:		98.03 %
# Epoch 99 of 200 took 4.207s
#   training loss:		0.061068
#   validation loss:		1.121446
#   validation accuracy:		98.02 %
# Epoch 100 of 200 took 4.202s
#   training loss:		0.060914
#   validation loss:		1.128242
#   validation accuracy:		98.05 %
# Epoch 101 of 200 took 4.203s
#   training loss:		0.060784
#   validation loss:		1.128568
#   validation accuracy:		98.04 %
# Epoch 102 of 200 took 4.224s
#   training loss:		0.060646
#   validation loss:		1.130066
#   validation accuracy:		98.01 %
# Epoch 103 of 200 took 4.223s
#   training loss:		0.060571
#   validation loss:		1.122599
#   validation accuracy:		98.05 %
# Epoch 104 of 200 took 4.301s
#   training loss:		0.060394
#   validation loss:		1.123527
#   validation accuracy:		98.02 %
# Epoch 105 of 200 took 4.219s
#   training loss:		0.060345
#   validation loss:		1.127449
#   validation accuracy:		98.04 %
# Epoch 106 of 200 took 4.218s
#   training loss:		0.060211
#   validation loss:		1.127229
#   validation accuracy:		98.02 %
# Epoch 107 of 200 took 4.221s
#   training loss:		0.060106
#   validation loss:		1.131389
#   validation accuracy:		98.03 %
# Epoch 108 of 200 took 4.316s
#   training loss:		0.059995
#   validation loss:		1.131322
#   validation accuracy:		98.02 %
# Epoch 109 of 200 took 4.223s
#   training loss:		0.059900
#   validation loss:		1.131568
#   validation accuracy:		98.02 %
# Epoch 110 of 200 took 4.224s
#   training loss:		0.059785
#   validation loss:		1.132591
#   validation accuracy:		98.05 %
# Epoch 111 of 200 took 4.224s
#   training loss:		0.059676
#   validation loss:		1.133867
#   validation accuracy:		98.02 %
# Epoch 112 of 200 took 4.223s
#   training loss:		0.059602
#   validation loss:		1.130297
#   validation accuracy:		98.02 %
# Epoch 113 of 200 took 4.222s
#   training loss:		0.059541
#   validation loss:		1.128096
#   validation accuracy:		98.05 %
# Epoch 114 of 200 took 4.223s
#   training loss:		0.059409
#   validation loss:		1.128233
#   validation accuracy:		98.02 %
# Epoch 115 of 200 took 4.222s
#   training loss:		0.059342
#   validation loss:		1.128873
#   validation accuracy:		98.05 %
# Epoch 116 of 200 took 4.218s
#   training loss:		0.059240
#   validation loss:		1.126915
#   validation accuracy:		98.03 %
# Epoch 117 of 200 took 4.207s
#   training loss:		0.059157
#   validation loss:		1.129763
#   validation accuracy:		98.05 %
# Epoch 118 of 200 took 4.208s
#   training loss:		0.059069
#   validation loss:		1.128076
#   validation accuracy:		98.04 %
# Epoch 119 of 200 took 4.208s
#   training loss:		0.058985
#   validation loss:		1.131046
#   validation accuracy:		98.05 %
# Epoch 120 of 200 took 4.208s
#   training loss:		0.058889
#   validation loss:		1.132394
#   validation accuracy:		98.06 %
# Epoch 121 of 200 took 4.207s
#   training loss:		0.058870
#   validation loss:		1.125261
#   validation accuracy:		98.03 %
# Epoch 122 of 200 took 4.208s
#   training loss:		0.058713
#   validation loss:		1.138189
#   validation accuracy:		98.05 %
# Epoch 123 of 200 took 4.204s
#   training loss:		0.058673
#   validation loss:		1.125254
#   validation accuracy:		98.06 %
# Epoch 124 of 200 took 4.197s
#   training loss:		0.058577
#   validation loss:		1.127340
#   validation accuracy:		98.07 %
# Epoch 125 of 200 took 4.199s
#   training loss:		0.058510
#   validation loss:		1.131025
#   validation accuracy:		98.04 %
# Epoch 126 of 200 took 4.197s
#   training loss:		0.058473
#   validation loss:		1.120959
#   validation accuracy:		98.03 %
# Epoch 127 of 200 took 4.199s
#   training loss:		0.058359
#   validation loss:		1.132252
#   validation accuracy:		98.05 %
# Epoch 128 of 200 took 4.223s
#   training loss:		0.058340
#   validation loss:		1.123132
#   validation accuracy:		98.05 %
# Epoch 129 of 200 took 4.222s
#   training loss:		0.058260
#   validation loss:		1.123752
#   validation accuracy:		98.00 %
# Epoch 130 of 200 took 4.223s
#   training loss:		0.058106
#   validation loss:		1.125440
#   validation accuracy:		98.06 %
# Epoch 131 of 200 took 4.222s
#   training loss:		0.058051
#   validation loss:		1.127718
#   validation accuracy:		98.06 %
# Epoch 132 of 200 took 4.222s
#   training loss:		0.058057
#   validation loss:		1.122720
#   validation accuracy:		98.02 %
# Epoch 133 of 200 took 4.223s
#   training loss:		0.057990
#   validation loss:		1.131286
#   validation accuracy:		98.01 %
# Epoch 134 of 200 took 4.222s
#   training loss:		0.057879
#   validation loss:		1.124008
#   validation accuracy:		98.05 %
# Epoch 135 of 200 took 4.223s
#   training loss:		0.057856
#   validation loss:		1.130746
#   validation accuracy:		98.01 %
# Epoch 136 of 200 took 4.223s
#   training loss:		0.057748
#   validation loss:		1.129343
#   validation accuracy:		98.02 %
# Epoch 137 of 200 took 4.222s
#   training loss:		0.057723
#   validation loss:		1.129295
#   validation accuracy:		98.02 %
# Epoch 138 of 200 took 4.223s
#   training loss:		0.057646
#   validation loss:		1.122759
#   validation accuracy:		98.03 %
# Epoch 139 of 200 took 4.223s
#   training loss:		0.057631
#   validation loss:		1.125275
#   validation accuracy:		98.05 %
# Epoch 140 of 200 took 4.223s
#   training loss:		0.057476
#   validation loss:		1.129076
#   validation accuracy:		98.03 %
# Epoch 141 of 200 took 4.222s
#   training loss:		0.057492
#   validation loss:		1.130031
#   validation accuracy:		98.03 %
# Epoch 142 of 200 took 4.222s
#   training loss:		0.057418
#   validation loss:		1.128965
#   validation accuracy:		98.02 %
# Epoch 143 of 200 took 4.223s
#   training loss:		0.057327
#   validation loss:		1.129651
#   validation accuracy:		98.05 %
# Epoch 144 of 200 took 4.224s
#   training loss:		0.057311
#   validation loss:		1.127684
#   validation accuracy:		98.02 %
# Epoch 145 of 200 took 4.222s
#   training loss:		0.057214
#   validation loss:		1.124283
#   validation accuracy:		98.02 %
# Epoch 146 of 200 took 4.223s
#   training loss:		0.057206
#   validation loss:		1.124499
#   validation accuracy:		98.04 %
# Epoch 147 of 200 took 4.223s
#   training loss:		0.057074
#   validation loss:		1.132934
#   validation accuracy:		97.99 %
# Epoch 148 of 200 took 4.223s
#   training loss:		0.057054
#   validation loss:		1.133854
#   validation accuracy:		98.02 %
# Epoch 149 of 200 took 4.223s
#   training loss:		0.056992
#   validation loss:		1.133109
#   validation accuracy:		98.02 %
# Epoch 150 of 200 took 4.222s
#   training loss:		0.056948
#   validation loss:		1.128550
#   validation accuracy:		98.02 %
# Epoch 151 of 200 took 4.222s
#   training loss:		0.056878
#   validation loss:		1.132218
#   validation accuracy:		97.99 %
# Epoch 152 of 200 took 4.223s
#   training loss:		0.056816
#   validation loss:		1.129106
#   validation accuracy:		98.01 %
# Epoch 153 of 200 took 4.223s
#   training loss:		0.056822
#   validation loss:		1.124916
#   validation accuracy:		98.03 %
# Epoch 154 of 200 took 4.223s
#   training loss:		0.056739
#   validation loss:		1.129580
#   validation accuracy:		98.01 %
# Epoch 155 of 200 took 4.279s
#   training loss:		0.056640
#   validation loss:		1.134368
#   validation accuracy:		97.99 %
# Epoch 156 of 200 took 4.207s
#   training loss:		0.056682
#   validation loss:		1.120842
#   validation accuracy:		98.05 %
# Epoch 157 of 200 took 4.208s
#   training loss:		0.056547
#   validation loss:		1.129208
#   validation accuracy:		98.05 %
# Epoch 158 of 200 took 4.202s
#   training loss:		0.056510
#   validation loss:		1.136710
#   validation accuracy:		98.00 %
# Epoch 159 of 200 took 4.202s
#   training loss:		0.056450
#   validation loss:		1.131820
#   validation accuracy:		98.02 %
# Epoch 160 of 200 took 4.201s
#   training loss:		0.056459
#   validation loss:		1.126040
#   validation accuracy:		98.01 %
# Epoch 161 of 200 took 4.202s
#   training loss:		0.056368
#   validation loss:		1.131021
#   validation accuracy:		98.05 %
# Epoch 162 of 200 took 4.202s
#   training loss:		0.056281
#   validation loss:		1.137816
#   validation accuracy:		98.00 %
# Epoch 163 of 200 took 4.202s
#   training loss:		0.056303
#   validation loss:		1.132901
#   validation accuracy:		98.05 %
# Epoch 164 of 200 took 4.202s
#   training loss:		0.056247
#   validation loss:		1.126183
#   validation accuracy:		98.01 %
# Epoch 165 of 200 took 4.201s
#   training loss:		0.056188
#   validation loss:		1.129444
#   validation accuracy:		98.02 %
# Epoch 166 of 200 took 4.202s
#   training loss:		0.056160
#   validation loss:		1.132867
#   validation accuracy:		98.00 %
# Epoch 167 of 200 took 4.201s
#   training loss:		0.056086
#   validation loss:		1.129182
#   validation accuracy:		98.04 %
# Epoch 168 of 200 took 4.201s
#   training loss:		0.056023
#   validation loss:		1.134262
#   validation accuracy:		97.98 %
# Epoch 169 of 200 took 4.201s
#   training loss:		0.056014
#   validation loss:		1.127148
#   validation accuracy:		98.02 %
# Epoch 170 of 200 took 4.201s
#   training loss:		0.055981
#   validation loss:		1.127228
#   validation accuracy:		98.00 %
# Epoch 171 of 200 took 4.200s
#   training loss:		0.055913
#   validation loss:		1.138191
#   validation accuracy:		98.02 %
# Epoch 172 of 200 took 4.201s
#   training loss:		0.055861
#   validation loss:		1.138597
#   validation accuracy:		98.00 %
# Epoch 173 of 200 took 4.216s
#   training loss:		0.055835
#   validation loss:		1.137635
#   validation accuracy:		98.01 %
# Epoch 174 of 200 took 4.201s
#   training loss:		0.055794
#   validation loss:		1.127008
#   validation accuracy:		98.01 %
# Epoch 175 of 200 took 4.201s
#   training loss:		0.055740
#   validation loss:		1.130091
#   validation accuracy:		97.99 %
# Epoch 176 of 200 took 4.201s
#   training loss:		0.055711
#   validation loss:		1.134103
#   validation accuracy:		98.02 %
# Epoch 177 of 200 took 4.201s
#   training loss:		0.055662
#   validation loss:		1.131606
#   validation accuracy:		98.02 %
# Epoch 178 of 200 took 4.202s
#   training loss:		0.055604
#   validation loss:		1.139157
#   validation accuracy:		98.01 %
# Epoch 179 of 200 took 4.201s
#   training loss:		0.055596
#   validation loss:		1.140007
#   validation accuracy:		97.98 %
# Epoch 180 of 200 took 4.201s
#   training loss:		0.055533
#   validation loss:		1.139210
#   validation accuracy:		97.98 %
# Epoch 181 of 200 took 4.202s
#   training loss:		0.055524
#   validation loss:		1.131904
#   validation accuracy:		98.02 %
# Epoch 182 of 200 took 4.201s
#   training loss:		0.055441
#   validation loss:		1.142663
#   validation accuracy:		97.97 %
# Epoch 183 of 200 took 4.203s
#   training loss:		0.055411
#   validation loss:		1.139534
#   validation accuracy:		97.98 %
# Epoch 184 of 200 took 4.202s
#   training loss:		0.055363
#   validation loss:		1.133050
#   validation accuracy:		98.01 %
# Epoch 185 of 200 took 4.202s
#   training loss:		0.055335
#   validation loss:		1.134494
#   validation accuracy:		97.98 %
# Epoch 186 of 200 took 4.201s
#   training loss:		0.055346
#   validation loss:		1.129184
#   validation accuracy:		98.00 %
# Epoch 187 of 200 took 4.202s
#   training loss:		0.055289
#   validation loss:		1.133436
#   validation accuracy:		97.98 %
# Epoch 188 of 200 took 4.202s
#   training loss:		0.055225
#   validation loss:		1.138365
#   validation accuracy:		97.98 %
# Epoch 189 of 200 took 4.202s
#   training loss:		0.055147
#   validation loss:		1.142053
#   validation accuracy:		97.98 %
# Epoch 190 of 200 took 4.201s
#   training loss:		0.055139
#   validation loss:		1.140561
#   validation accuracy:		97.98 %
# Epoch 191 of 200 took 4.201s
#   training loss:		0.055114
#   validation loss:		1.132361
#   validation accuracy:		98.00 %
# Epoch 192 of 200 took 4.201s
#   training loss:		0.055094
#   validation loss:		1.138311
#   validation accuracy:		97.98 %
# Epoch 193 of 200 took 4.202s
#   training loss:		0.055086
#   validation loss:		1.128375
#   validation accuracy:		98.01 %
# Epoch 194 of 200 took 4.201s
#   training loss:		0.054996
#   validation loss:		1.141298
#   validation accuracy:		97.96 %
# Epoch 195 of 200 took 4.201s
#   training loss:		0.054990
#   validation loss:		1.142914
#   validation accuracy:		97.94 %
# Epoch 196 of 200 took 4.202s
#   training loss:		0.054896
#   validation loss:		1.146509
#   validation accuracy:		98.00 %
# Epoch 197 of 200 took 4.201s
#   training loss:		0.054955
#   validation loss:		1.137226
#   validation accuracy:		97.98 %
# Epoch 198 of 200 took 4.201s
#   training loss:		0.054843
#   validation loss:		1.135553
#   validation accuracy:		97.97 %
# Epoch 199 of 200 took 4.202s
#   training loss:		0.054874
#   validation loss:		1.134455
#   validation accuracy:		97.94 %
# Epoch 200 of 200 took 4.201s
#   training loss:		0.054771
#   validation loss:		1.151700
#   validation accuracy:		97.94 %

# %% [markdown]
# Now let's create a function that computes the latent representation variables z so we can visualize them on the test set.

# %%
z = nn.layers.get_output(l_latent)

compute_z = theano.function(
    [], z,
    givens={
        x: dataset['X_test'],
    },
)

z_vals = compute_z()

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(z_vals[:, 0], z_vals[:, 1], alpha=0.1)
plt.show()

# %% [markdown]
# This corresponds to figure 4a in the paper. Our latent variables have a smaller magnitude overall, but exhibit a roughly Gaussian distribution just like in the paper.
#
# Now let's generate some reconstructions. Our aim is to reproduce figures 4b and 4c. We'll need to compile a function that allows us to set the desired values for the latent variables `y` and `z`.
#
# Lasagne makes it possible to map any layer in the network to a custom expression by supplying a dictionary to `nn.layers.get_output()`. We'll make use of this to 'clamp' the observed and latent representation variables.

# %%
y_clamped = T.ivector('y_clamped')
z_clamped = T.matrix('z_clamped')

x_recon = nn.layers.get_output(l_decoder_out, {
        l_observed: nn.utils.one_hot(y_clamped, m=10),
        l_latent: z_clamped,
    })

reconstruct = theano.function([y_clamped, z_clamped], x_recon)

# %%
ys = np.repeat(np.arange(10), 9).astype('int32')
zs = np.tile(np.linspace(-0.5, 0.5, 9), 10).astype(theano.config.floatX)
z1s = np.vstack([zs, np.zeros_like(zs)]).T
z2s = np.vstack([np.zeros_like(zs), zs]).T

# %%
reconstructions_z1 = reconstruct(ys, z1s)
reconstructions_z2 = reconstruct(ys, z2s)
# Out:
# (90, 4096)

# %%
im1 = reconstructions_z1.reshape(10, 9, w, h).transpose(1, 2, 0, 3).reshape(9 * w, 10 * h)
plt.imshow(im1, cmap=plt.cm.gray)
plt.show()

# %%
im2 = reconstructions_z2.reshape(10, 9, w, h).transpose(1, 2, 0, 3).reshape(9 * w, 10 * h)
plt.imshow(im2, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# The reconstructions show some interesting structure as `z1` and `z2` are varied. Pretty cool!

# %%
# Out:
# 64
